# %% [markdown]
# # 🌀 Bienvenidos al Laboratorio de Caos
#
# ## Explorando el Mapa Logístico Extendido
#
# ---
#
# ### 👋 ¡Hola!
#
# Estás a punto de explorar uno de los sistemas más fascinantes de las matemáticas: **el mapa logístico extendido**.
#
# ### 🎯 ¿Qué aprenderás hoy?
#
# - Cómo pequeños cambios pueden causar grandes diferencias (¡el efecto mariposa!)
# - Programación básica en Python
# - Visualización de sistemas caóticos
# - Espacio de fases y diagramas de telaraña
#
# ### 📚 Instrucciones
#
# 1. **Abre el notebook principal:** En el panel izquierdo, haz doble clic en `mapa_logistico_ext.ipynb`
# 2. **Sigue las instrucciones** en cada celda
# 3. **Ejecuta el código:** Presiona `Shift + Enter` o haz clic en el botón ▶️
# 4. **Experimenta:** ¡No tengas miedo de cambiar valores y ver qué pasa!
#
# ### ⚠️ Importante
#
# - Todo funciona en tu navegador (¡nada se guarda en un servidor!)
# - Si recargas la página, perderás tu progreso
# - Para guardar tu trabajo: `File > Download`
#
# ### 🚀 ¡Comienza!
#
# **→ Abre `mapa_logistico_ext.ipynb` en el panel izquierdo para empezar →**
#
# ---
#
# ### 🆘 ¿Necesitas ayuda?
#
# - **El código no funciona:** Asegúrate de haber ejecutado todas las celdas anteriores en orden
# - **Todo se ve raro:** Recarga la página (perderás cambios no guardados)
# - **Error de importación:** Espera unos segundos, los paquetes se están instalando
#
# ### 📖 Recursos adicionales
#
# Si quieres profundizar:
# - [Video: El mapa logístico y el caos](https://www.youtube.com/watch?v=ovJcsL7vyrk) (Veritasium)
# - [Artículo: Chaos Theory](https://en.wikipedia.org/wiki/Chaos_theory) (Wikipedia)
# - [Visualización interactiva](https://www.complexity-explorables.org/) (Complexity Explorables)
#
# ---
#
# **¡Diviértete explorando el caos!** 🦋

# %% [markdown]
# ## 🧪 Prueba rápida del entorno
#
# Ejecuta la siguiente celda para verificar que todo funciona:

# %%
# Prueba rápida del entorno Python
import sys
print(f"✓ Python {sys.version.split()[0]} funcionando")

try:
    import numpy as np
    print("✓ NumPy disponible")
except:
    print("⏳ NumPy instalándose...")

try:
    import matplotlib.pyplot as plt
    print("✓ Matplotlib disponible")
except:
    print("⏳ Matplotlib instalándose...")

try:
    import ipywidgets
    print("✓ Widgets interactivos disponibles")
except:
    print("⏳ ipywidgets instalándose...")

print("\n🎉 ¡Todo listo! Abre mapa_logistico_ext.ipynb para comenzar.")
