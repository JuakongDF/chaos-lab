# %% [markdown]
# # EVALUACIÓN - GRUPO 5
# **Lucas Sepulveda, Mateo Luarte, Mateo Fernandez, Julio Humerez**
#
# **Proyecto:** Modelo SIR Discreto para predicción de COVID-19 en Chile
#
# **Fecha de evaluación:** Noviembre 2024
#
# ---

# %% [markdown]
# ## Puntaje
#
# | Sección | Puntos |
# |---------|--------|
# | 1. Título y Abstract | 10/10 |
# | 2. Introducción | 20/20 |
# | 3. Marco Teórico | 18/20 |
# | 4. Código y Simulaciones | 0/25 |
# | 5. Análisis de Resultados | 5/30 |
# | 6. Discusión y Conclusiones | 12/15 |
# | 7. Presentación y Formato | 5/10 |
# | **TOTAL** | **70 (80%)** |

# %% [markdown]
# ## Fortalezas
#
# - Introducción excelente: contexto claro con estadísticas específicas (5.2M casos, 52K muertes en Chile), motivación bien desarrollada, relevancia conectada con aprendizajes para futuras pandemias
# - Pregunta de investigación específica y testeable: "¿Qué tan preciso es el modelo SIR discreto...?"
# - Hipótesis bien formulada con predicciones claras sobre precisión y limitaciones esperadas
# - Abstract bien estructurado (150-250 palabras) con problema, método, resultados y conclusiones
# - Marco teórico incluye ecuaciones del modelo SIR: $S_{n+1} = S_n - \beta S_n I_n$, $I_{n+1} = I_n + \beta S_n I_n - \gamma I_n$, $R_{n+1} = R_n + \gamma I_n$
# - Parámetros definidos correctamente: S (susceptibles), I (infectados), R (recuperados), β (tasa de contacto), γ (tasa de recuperación), R₀ (número reproductivo)
# - Tabla comparativa datos reales vs simulados presente (agosto 2020 - agosto 2021) con valores de S, I, R
# - Discusión bien estructurada: analiza hallazgos, confirma hipótesis, conecta con literatura, implicaciones prácticas claras
# - Identifica limitaciones correctamente: modelo no incluye cuarentenas/vacunación, supone comportamiento homogéneo, parámetros fijos
# - Propone trabajo futuro con consideración del trade-off complejidad/interpretabilidad
# - Narrativa coherente y redacción clara en todo el documento

# %% [markdown]
# ## Pendiente
#
# - **PROBLEMA CRÍTICO - Código inexistente (0/25 puntos perdidos):**
#   - NO implementaron el modelo SIR discreto en absoluto
#   - Notebook solo contiene código de ejemplo del mapa logístico (plantilla sin modificar)
#   - No hay función que ejecute las ecuaciones $S_{n+1}$, $I_{n+1}$, $R_{n+1}$ presentadas en marco teórico
#   - Presentan tabla de "resultados simulados" pero la simulación NO EXISTE en el código
#   - Todo el análisis de resultados se basa en simulaciones fantasma
# - **Gráficos ausentes (-25 puntos adicionales en Análisis):**
#   - No hay visualización de series temporales (S, I, R vs tiempo)
#   - No hay comparación gráfica datos reales vs simulados
#   - No hay diagrama de fase ni espacio de estados
#   - Todos los gráficos del notebook son del mapa logístico (plantilla)
# - **Referencias incompletas (-5 puntos en Presentación):**
#   - Solo 3 links sin formato apropiado (no APA/IEEE/otro estándar)
#   - Falta descripción del contenido de cada fuente
#   - Secciones "Referencias" y "Recursos Online" casi vacías
# - **Ecuaciones sin LaTeX (-2 puntos en Marco Teórico):**
#   - Ecuaciones presentadas como texto plano en lugar de formato matemático
#   - Falta renderizar con LaTeX para claridad profesional
# - **Sin análisis cuantitativo:**
#   - No calcula métricas de error (MSE, RMSE, R²) para validar ajuste
#   - No muestra cómo ajustaron β y γ a datos del MINSAL
#   - No explora sensibilidad paramétrica
