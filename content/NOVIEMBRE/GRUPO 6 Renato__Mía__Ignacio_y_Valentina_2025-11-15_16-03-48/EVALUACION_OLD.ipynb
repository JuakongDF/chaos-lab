# %% [markdown]
# # EVALUACIÓN: GRUPO 6 - Renato, Mía, Ignacio y Valentina
#
# **Modelo:** Tent Map (Caos Determinista) + Mapa Logístico Clásico
# **Fecha de evaluación:** Noviembre 21, 2025
#
# **Archivos revisados:**
# - `Ignacio_Alfonso_Bustos_Saez_2025-11-15_16-02-00.ipynb` (código Python)
# - `Renato__Mía__Ignacio_y_Valentina_2025-11-15_16-03-48.ipynb` (planificación)
#
# ---
#
# ## ⚠️ PROBLEMA CRÍTICO
#
# Este grupo entregó **SOLO CÓDIGO Python** sin ninguna estructura científica. No es un informe de investigación, es un archivo de programación sin contexto académico.
#
# **Lo que tienen:** Código funcional del Tent Map y visualizaciones
# **Lo que falta:** Todo el componente científico (introducción, marco teórico, análisis, conclusiones)

# %% [markdown]
# ## Resumen
# - **Puntaje total obtenido: 29 / 130 puntos**
# - **Porcentaje: 22.3%**
# - **Equivalente escala (90 pts = 100%): 32.2%**
# - **Nota: 1.5 (escala 1-7)**
# - **Calificación: MUY INSUFICIENTE** ❌
#
# **Distribución:**
# - Código funcional: 14/25 ✅ (única fortaleza)
# - Todo lo demás: 15/105 ❌ (componente científico ausente)

# %% [markdown]
# ## 1) Título y Abstract (máx. 10 pts) — 0 / 10
#
# **Observaciones:**
# - ❌ **Sin título:** No hay ningún título descriptivo del proyecto
# - ❌ **Sin abstract:** No hay resumen científico (150-250 palabras)
# - El archivo solo contiene código Python sin introducción
#
# **Recomendación:**
# - Agregar título descriptivo que incluya "Tent Map" y el fenómeno estudiado (ej: "Análisis Comparativo del Caos Determinista en el Tent Map y el Mapa Logístico")
# - Escribir abstract con: problema, método, resultados principales, conclusión

# %% [markdown]
# ## 2) Introducción y Planteamiento (máx. 20 pts) — 3 / 20
#
# **Observaciones:**
# - ❌ **Sin introducción:** No hay contexto sobre por qué estudiar el Tent Map o el caos determinista
# - ⚠️ **Pregunta parcial:** En el archivo de planificación existe la pregunta ("¿Qué condiciones iniciales dentro del modelo tent map llevan a la extinción, ciclos, estabilidad o caos y como se diferencia visualmente de otros modelos como el mapa logístico?") pero NO está en el informe principal
# - ⚠️ **Hipótesis incompleta:** Hay un esbozo ("Se espera que en el tent map los valores de 'r' para llegar a los diveros casos...") con errores ortográficos y sin desarrollar
# - ❌ **Sin motivación:** No explica la relevancia del efecto mariposa, caos determinista, o aplicaciones
#
# **Puntaje parcial:** 2 pts por pregunta en planificación + 1 pt por esbozo de hipótesis = 3/20
#
# **Recomendación:**
# - Escribir introducción de 300-500 palabras sobre caos determinista, Tent Map, y su importancia
# - Trasladar la pregunta de investigación al informe principal y refinarla
# - Completar la hipótesis con predicciones específicas sobre valores de μ

# %% [markdown]
# ## 3) Marco Teórico (máx. 20 pts) — 0 / 20
#
# **Observaciones:**
# - ❌ **Sin ecuaciones:** No presentan la ecuación del Tent Map en LaTeX:
#   $$x_{n+1} = \\begin{cases} \\mu x_n & \\text{si } x_n < 0.5 \\\\ \\mu (1 - x_n) & \\text{si } x_n \\geq 0.5 \\end{cases}$$
# - ❌ **Sin explicación de parámetros:** No explican qué significa μ (mu), o las condiciones x < 0.5 vs x ≥ 0.5
# - ❌ **Sin teoría del caos:** No mencionan exponente de Lyapunov, sensibilidad a condiciones iniciales, o comportamiento caótico
# - ❌ **Sin referencias:** No citan ninguna fuente científica sobre Tent Map o sistemas dinámicos
#
# **Recomendación:**
# - Agregar sección "Marco Teórico" con ecuaciones del Tent Map en LaTeX
# - Explicar significado de cada parámetro y variable
# - Describir comportamiento esperado: convergencia, ciclos, caos según valor de μ
# - Incluir al menos 3-5 referencias científicas (papers, libros, sitios educativos)

# %% [markdown]
# ## 4) Implementación del Código (máx. 25 pts) — 14 / 25
#
# **Observaciones:**
# - ✅ **Funcionalidad:** El código implementa correctamente el Tent Map (`generarPasos`) y el Mapa Logístico (`mapa_logistico_clasico`). Genera secuencias y visualizaciones comparativas. (7/9 pts)
#   ```python
#   def generarPasos(u, x):
#       if x < 0.5: return u*x
#       elif x >= 0.5: return u*(1-x)
#   ```
# - ⚠️ **Documentación limitada:** Algunas funciones tienen docstrings básicos, pero muchas partes carecen de comentarios explicativos (3/9 pts)
# - ⚠️ **Organización mejorable:** Código dividido en funciones (`generarPasos`, `secuencia`, `cobweb_sequence`), pero con código repetido y falta modularidad clara (4/7 pts)
# - ⚠️ **Celdas no ejecutadas:** El notebook tiene outputs previos pero no muestra ejecución reciente
#
# **Fortalezas técnicas:**
# - ✅ Implementa Tent Map con condicional correcto
# - ✅ Implementa Mapa Logístico para comparación
# - ✅ Genera diagramas de telaraña (cobweb plots)
# - ✅ Usa Plotly con subplots para comparaciones visuales
# - ✅ Widget interactivo con controles de μ y r
#
# **Recomendación:**
# - Agregar comentarios explicativos en cada sección del código
# - Ejecutar todas las celdas antes de entregar
# - Eliminar código repetido y mejorar modularidad

# %% [markdown]
# ## 5) Análisis y Resultados (máx. 30 pts) — 9 / 30
#
# **Observaciones:**
# - ⚠️ **Gráficos sin interpretación:** El código genera múltiples visualizaciones (series temporales comparadas, diagramas de telaraña) pero **NO HAY TEXTO** que explique qué muestran (6/10 pts)
# - ⚠️ **Exploración básica:** El widget interactivo permite variar μ, r, y condiciones iniciales, pero no hay análisis sistemático de diferentes regímenes (extinción, ciclos, caos) (3/10 pts)
# - ❌ **Sin interpretación escrita:** No hay ningún análisis textual de los resultados. Solo código que genera gráficos sin narrativa (0/10 pts)
#
# **Lo que falta:**
# - Explicación de qué muestran los gráficos
# - Análisis de diferentes valores de μ: ¿Cuándo hay convergencia? ¿Cuándo caos?
# - Comparación entre Tent Map y Mapa Logístico: ¿En qué se diferencian?
# - Análisis de sensibilidad a condiciones iniciales
#
# **Recomendación:**
# - Agregar celdas markdown DESPUÉS de cada gráfico explicando qué muestra
# - Realizar análisis sistemático: probar μ = 1.0, 1.5, 1.8, 2.0 y describir comportamiento
# - Comparar resultados de ambos modelos con interpretación

# %% [markdown]
# ## 6) Discusión y Conclusiones (máx. 15 pts) — 0 / 15
#
# **Observaciones:**
# - ❌ **Sin discusión:** No hay análisis de hallazgos, comparación con literatura, ni mención de implicaciones
# - ❌ **Sin conclusiones:** No responden su propia pregunta de investigación ("¿Qué condiciones iniciales llevan a extinción, ciclos, estabilidad o caos?")
# - ❌ **Sin limitaciones:** No mencionan limitaciones del modelo o suposiciones
# - ❌ **Sin trabajo futuro:** No proponen extensiones o mejoras
#
# **Lo que deberían incluir:**
# - **Discusión:** ¿Qué encontraron? ¿Cómo se compara Tent Map con Mapa Logístico? ¿Qué valores de μ producen caos?
# - **Conclusiones:** 3-5 conclusiones concretas basadas en las simulaciones
# - **Limitaciones:** Precisión numérica, número de iteraciones, rango de parámetros explorados
# - **Trabajo futuro:** Análisis de bifurcaciones, exponente de Lyapunov, aplicaciones
#
# **Recomendación:**
# - Agregar sección "Discusión" analizando los resultados y conectando con el efecto mariposa
# - Agregar sección "Conclusiones" con 3-5 puntos concretos que respondan la pregunta de investigación

# %% [markdown]
# ## 7) Presentación y Calidad General (máx. 10 pts) — 3 / 10
#
# **Observaciones:**
# - ❌ **Sin estructura científica:** El archivo es solo código Python, no sigue formato de informe (Abstract, Introducción, Métodos, Resultados, Discusión, Conclusiones)
# - ❌ **Casi sin texto:** Prácticamente no hay redacción científica. El poco texto en el archivo de planificación tiene errores ortográficos ("diveros" en vez de "diversos") (1/5 pts)
# - ⚠️ **Organización limitada:** El código está organizado en celdas pero sin narrativa que las conecte (2/5 pts)
#
# **Errores específicos:**
# - Archivo entregado es código sin contexto académico
# - Falta toda la estructura de un informe científico
# - No hay transiciones entre secciones ni narrativa coherente
#
# **Recomendación:**
# - Reestructurar completamente el notebook siguiendo formato científico
# - Agregar celdas markdown con texto explicativo entre código
# - Revisar ortografía y redacción
# - Seguir el template proporcionado con todas las secciones

# %%
# Cálculo automático de totales
scores = {
    'Titulo_Abstract': (0, 10),
    'Introduccion': (3, 20),
    'Marco_Teorico': (0, 20),
    'Implementacion_Codigo': (14, 25),
    'Analisis_Resultados': (9, 30),
    'Discusion_Conclusiones': (0, 15),
    'Presentacion_Calidad': (3, 10)
}

total = sum(v[0] for v in scores.values())
max_total = sum(v[1] for v in scores.values())
pct = 100 * total / max_total if max_total > 0 else 0
scaled_90 = total / max_total * 90 if max_total > 0 else 0

print("=" * 60)
print("RESUMEN DE EVALUACIÓN - GRUPO 6")
print("=" * 60)
print(f"1. Título y Abstract:        {scores['Titulo_Abstract'][0]}/{scores['Titulo_Abstract'][1]} ❌")
print(f"2. Introducción:             {scores['Introduccion'][0]}/{scores['Introduccion'][1]} ⚠️")
print(f"3. Marco Teórico:            {scores['Marco_Teorico'][0]}/{scores['Marco_Teorico'][1]} ❌")
print(f"4. Código y Simulaciones:    {scores['Implementacion_Codigo'][0]}/{scores['Implementacion_Codigo'][1]} ✅ (única fortaleza)")
print(f"5. Análisis de Resultados:   {scores['Analisis_Resultados'][0]}/{scores['Analisis_Resultados'][1]} ⚠️")
print(f"6. Discusión y Conclusiones: {scores['Discusion_Conclusiones'][0]}/{scores['Discusion_Conclusiones'][1]} ❌")
print(f"7. Presentación y Formato:   {scores['Presentacion_Calidad'][0]}/{scores['Presentacion_Calidad'][1]} ⚠️")
print("-" * 60)
print(f"PUNTAJE TOTAL:               {total}/{max_total}")
print(f"PORCENTAJE:                  {pct:.1f}%")
print(f"NOTA (90 pts = 100%):        {scaled_90:.1f}%")
print("=" * 60)

if total >= 90:
    print("✅ EXCELENTE - Cumple con todos los requisitos")
elif total >= 70:
    print("✅ APROBADO - Buen trabajo con oportunidades de mejora")
elif total >= 50:
    print("⚠️  SUFICIENTE - Trabajo básico, necesita mejoras significativas")
else:
    print("❌ INSUFICIENTE - No cumple con los requisitos mínimos")
    print("\n⚠️  URGENTE: Este es un archivo de código, no un informe científico")
    print("Se requiere agregar TODA la estructura académica para aprobar")

# %% [markdown]
# ## Resumen de Recomendaciones Principales
#
# ### ⚠️ PROBLEMA FUNDAMENTAL
# **Confundieron "proyecto de programación" con "proyecto de investigación científica"**
#
# Tienen las herramientas técnicas (código funcional, gráficos) pero les falta **completamente** el componente académico.
#
# ---
#
# ### Recomendaciones URGENTES para aprobar:
#
# 1. **Agregar estructura científica completa** (CRÍTICO)
#    - Título descriptivo del proyecto
#    - Abstract de 150-250 palabras
#    - Introducción de 300-500 palabras sobre caos determinista
#    - Marco Teórico con ecuaciones del Tent Map en LaTeX
#
# 2. **Escribir análisis de resultados** (CRÍTICO)
#    - Explicar qué muestra cada gráfico
#    - Analizar diferentes valores de μ (convergencia, ciclos, caos)
#    - Comparar Tent Map vs Mapa Logístico
#    - Documentar sensibilidad a condiciones iniciales
#
# 3. **Agregar Discusión y Conclusiones** (CRÍTICO)
#    - Responder la pregunta de investigación
#    - Discutir implicaciones del "efecto mariposa"
#    - Mencionar limitaciones del modelo
#    - 3-5 conclusiones concretas
#
# 4. **Incluir referencias bibliográficas**
#    - Mínimo 3-5 fuentes sobre Tent Map, caos determinista, o sistemas dinámicos
#
# 5. **Mejorar presentación**
#    - Agregar texto explicativo entre secciones de código
#    - Seguir formato científico estándar
#    - Ejecutar todas las celdas antes de entregar
#
# ---
#
# ### Potencial del trabajo si se completa:
#
# **Puntaje actual:** 29/130 (22.3%)
# **Puntaje potencial con mejoras:** 75-85/130 (58-65%)
#
# **Desglose de puntos recuperables:**
# - Introducción + Marco Teórico: +15 pts
# - Análisis e interpretación escrita: +20 pts
# - Discusión + Conclusiones: +10 pts
# - Formato científico + Referencias: +5 pts
#
# **Podrían aumentar de 29 a ~80 puntos agregando el componente científico.**
#
# ---
#
# ### Comparación con otros grupos:
#
# | Grupo | Puntaje | Problema | Solución |
# |-------|---------|----------|----------|
# | GRUPO 4 | 116/130 | Ninguno | Excelente integración código + narrativa |
# | GRUPO 5 | 70/130 | Código ausente | Implementar modelo SIR |
# | **GRUPO 6** | **29/130** | **Narrativa ausente** | **Agregar estructura científica** |
#
# **GRUPO 6 tiene el problema inverso al GRUPO 5:**
# - Grupo 5: Excelente teoría, sin código
# - Grupo 6: Buen código, sin teoría
#
# ---
#
# ### Mensaje para el grupo:
#
# El código que implementaron es **técnicamente correcto** y muestra comprensión del Tent Map. Sin embargo, un proyecto de investigación requiere:
#
# 1. **Contexto:** ¿Por qué estudiamos esto?
# 2. **Teoría:** ¿Qué dice la ciencia sobre este modelo?
# 3. **Análisis:** ¿Qué significan los resultados?
# 4. **Conclusiones:** ¿Qué aprendimos?
#
# **No basta con programar bien. Hay que comunicar científicamente.**
#
# ---
#
# **Próximos pasos sugeridos:**
# 1. Usar el template del proyecto (PROYECTO_INVESTIGACION_NOVIEMBRE.ipynb)
# 2. Copiar el código existente a las secciones apropiadas
# 3. Agregar TODAS las secciones textuales faltantes
# 4. Ejecutar el notebook completo
# 5. Reenviar antes de la fecha límite
