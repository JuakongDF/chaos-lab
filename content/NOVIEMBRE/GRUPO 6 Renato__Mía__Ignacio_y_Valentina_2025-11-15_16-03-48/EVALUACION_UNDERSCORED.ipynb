# %% [markdown]
# # EVALUACIÓN - GRUPO 6
# **Renato, Mía, Ignacio, Valentina**
#
# **Proyecto:** Análisis comparativo Tent Map vs Mapa Logístico
#
# **Fecha de evaluación:** Noviembre 2024
#
# ---

# %% [markdown]
# ## Puntaje
#
# | Sección | Puntos |
# |---------|--------|
# | 1. Título y Abstract | 0/10 |
# | 2. Introducción | 8/20 |
# | 3. Marco Teórico | 5/20 |
# | 4. Código y Simulaciones | 20/25 |
# | 5. Análisis de Resultados | 12/30 |
# | 6. Discusión y Conclusiones | 8/15 |
# | 7. Presentación y Formato | 3/10 |
# | **TOTAL** | **56/130 (43.1%)** |

# %% [markdown]
# ## Fortalezas
#
# - Código funcional y bien implementado: función `generarPasos(u, x)` ejecuta correctamente Tent Map con condicional `if x < 0.5: u*x` y `elif x >= 0.5: u*(1-x)`
# - Implementación comparativa sólida: tiene tanto Tent Map como Mapa Logístico programados para análisis lado a lado
# - Visualizaciones técnicas presentes: código genera diagramas de telaraña (cobweb), diagramas de bifurcación, series temporales comparadas usando Plotly con subplots
# - Widget interactivo funcional: permite variar parámetros μ (Tent Map) y r (Mapa Logístico) con controles deslizantes
# - Pregunta de investigación clara: "¿Qué condiciones iniciales dentro del tent map llevan a extinción, ciclos, estabilidad o caos y cómo se diferencia visualmente del mapa logístico?"
# - Hipótesis bien formulada: predicen diferencias leves cualitativas pero mayor sensibilidad al caos en Tent Map
# - Motivación genuina: curiosidad por comparar dos modelos "sencillos" con aplicaciones distintas (encriptación vs poblaciones)
# - Resultados experimentales documentados: rangos de parámetros identificados para ambos modelos (μ < 1 extinción, μ = 1 estabilidad, 1 < μ < 2 caos, μ = 2 ciclos/extinción para Tent Map)
# - Referencias incluidas: 3 fuentes citadas (2 tesis, 1 blog técnico)
# - Reflexión metodológica: describen proceso experimental de "ir ingresando datos, anotarlos manualmente y observar rangos"

# %% [markdown]
# ## Pendiente
#
# - **Sin título formal del proyecto** (-10 puntos): documento carece de título científico descriptivo en sección inicial
# - **Sin abstract estructurado** (-10 puntos adicionales): no hay resumen ejecutivo de 150-250 palabras con problema-método-resultados-conclusión
# - **Ecuaciones sin formato LaTeX** (-10 puntos en Marco Teórico): Tent Map debería presentarse como $x_{n+1} = \begin{cases} \mu x_n & \text{si } x_n < 0.5 \\ \mu (1 - x_n) & \text{si } x_n \geq 0.5 \end{cases}$, actualmente solo está en texto narrativo
# - **Marco teórico incompleto** (-5 puntos adicionales): no define formalmente parámetros, no menciona teoría del caos (exponente Lyapunov, sensibilidad a condiciones iniciales)
# - **Gráficos sin interpretación escrita** (-18 puntos en Análisis): código genera visualizaciones pero NO hay celdas markdown explicando qué muestran cada gráfico
# - **Análisis cualitativo sin profundidad cuantitativa**: identifican rangos de parámetros pero no calculan métricas (exponente Lyapunov, punto de Feigenbaum exacto, error entre modelos)
# - **Discusión superficial** (-7 puntos en Discusión): conclusión principal presente ("no son similares") pero falta discusión de implicaciones, conexión profunda con literatura, análisis de por qué difieren
# - **Formato no científico estándar** (-7 puntos en Presentación): estructura es narrativa corrida + código, no sigue formato Abstract-Introducción-Marco Teórico-Metodología-Resultados-Discusión-Conclusiones con secciones claramente delimitadas
# - **Referencias sin formato estándar**: citaciones no siguen APA, IEEE u otro formato académico consistente
# - **Celdas sin ejecutar**: notebook tiene outputs antiguos pero no muestra ejecución reciente

# %% [markdown]
# ## Recomendaciones
#
# **Para estructura científica (recuperar ~20 puntos):**
#
# 1. **Agregar título descriptivo** al inicio: "Análisis Comparativo del Comportamiento Caótico en Tent Map y Mapa Logístico: Sensibilidad Paramétrica y Bifurcaciones"
#
# 2. **Escribir abstract estructurado** (150-250 palabras) con: contexto (dos modelos simples, aplicaciones distintas), método (simulaciones Python, comparación visual), resultados principales (rangos de μ y r identificados), conclusión (proporcionalmente muy distintos)
#
# 3. **Reformatear como informe científico** con secciones claramente delimitadas: usar celdas markdown con títulos ## Introducción, ## Marco Teórico, ## Metodología, ## Resultados, ## Discusión, ## Conclusiones
#
# **Para marco teórico (recuperar ~10 puntos):**
#
# 4. **Renderizar ecuaciones en LaTeX** para Tent Map y Mapa Logístico
#
# 5. **Agregar teoría del caos**: definir exponente de Lyapunov, explicar sensibilidad a condiciones iniciales, mencionar constante de Feigenbaum
#
# 6. **Explicar parámetros formalmente**: definir μ (parámetro de control Tent Map), r (tasa crecimiento Mapa Logístico), x (población normalizada)
#
# **Para análisis (recuperar ~18 puntos):**
#
# 7. **Agregar celdas markdown DESPUÉS de cada gráfico** explicando qué muestra: ejemplo "El diagrama de bifurcación para Tent Map muestra que el caos aparece inmediatamente después de μ = 1, mientras que en el Mapa Logístico el caos comienza gradualmente después de r ≈ 3.57"
#
# 8. **Incluir análisis cuantitativo**: calcular exponente de Lyapunov para ambos modelos, calcular punto de transición al caos exacto, graficar comparación lado a lado de λ(μ) vs λ(r)
#
# 9. **Crear tabla comparativa** con valores críticos para cada modelo:
#
# | Comportamiento | Tent Map (μ) | Mapa Logístico (r) |
# |---|---|---|
# | Extinción | μ < 1 | r < 1 |
# | Estabilidad | μ = 1 | 1 < r < 3 |
# | Caos | 1 < μ < 2 | 3.57 < r < 4 |
#
# **Para discusión (recuperar ~7 puntos):**
#
# 10. **Profundizar en el "por qué"**: explicar por qué Tent Map tiene transición más abrupta al caos (función lineal por tramos vs función cuadrática)
#
# 11. **Conectar con aplicaciones**: discutir implicaciones de mayor sensibilidad de Tent Map para encriptación (bueno) vs predicción poblacional (malo)
#
# 12. **Mencionar limitaciones**: precisión numérica, número de iteraciones exploradas, falta de análisis de dimensión fractal
#
# **Prioridad inmediata:** Ejecutar todas las celdas, agregar interpretación escrita de gráficos, reestructurar con secciones científicas claras.
#
# **Este trabajo tiene el problema inverso al GRUPO 5**: ustedes tienen buen código sin narrativa científica suficiente; GRUPO 5 tiene buena narrativa sin código. Ambos necesitan integrar ambos componentes.
