# %% [markdown]
# # EVALUACIÓN - GRUPO 6
# **Renato, Mía, Ignacio, Valentina**
#
# **Proyecto:** Comparando modelos: Tent Map y Mapa Logístico
#
# **Fecha de evaluación:** Noviembre 2024
#
# ---

# %% [markdown]
# ## Puntaje
#
# | Sección | Puntos |
# |---------|--------|
# | 1. Título y Abstract | 7/10 |
# | 2. Introducción | 18/20 |
# | 3. Marco Teórico | 14/20 |
# | 4. Código y Simulaciones | 23/25 |
# | 5. Análisis de Resultados | 24/30 |
# | 6. Discusión y Conclusiones | 13/15 |
# | 7. Presentación y Formato | 7/10 |
# | **TOTAL** | **106 (100%)** |

# %% [markdown]
# ## Fortalezas
#
# - Título claro y descriptivo
# - Pregunta de investigación muy bien formulada
# - Hipótesis clara y bien fundamentada
# - Motivación genuina y bien articulada
# - Metodología claramente descrita
# - Resultados experimentales completos y bien documentados para AMBOS modelos
# - Código técnicamente excelente:
# - Múltiples tipos de visualización programados: series temporales, diagramas de bifurcación (ambos modelos), diagramas de telaraña (cobweb)
# - Widget interactivo funcional con controles para variar μ, r, condiciones iniciales, número de pasos y seleccionar tipo de visualización
# - Referencias incluidas: 3 fuentes (2 tesis académicas: João 2013 sobre dinámica mapa logístico, Rojas 2023 sobre encriptación con Tent; 1 blog técnico)
# - Reflexión sobre proceso: describen desafíos (programar Tent Map, tutoriales en inglés) y método experimental

# %% [markdown]
# ## Pendiente
#
# - **Teoría del caos no mencionada explícitamente**: aunque identifican comportamiento caótico, no definen conceptos como sensibilidad a condiciones iniciales o la constante de Feigenbaum
# - **Discusión podría profundizar más** (-2 puntos): concluyen que son "proporcionalmente muy distintos" pero podrían explicar POR QUÉ (función lineal por tramos vs cuadrática, implicaciones para aplicaciones)
# - **Formato podría mejorarse** (-3 puntos en Presentación): aunque contenido está completo, sería más claro con secciones explícitas (## Introducción, ## Marco Teórico, ## Metodología, ## Resultados, ## Conclusiones)
