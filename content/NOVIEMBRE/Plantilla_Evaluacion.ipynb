# %% [markdown]
# # EVALUACIÓN: [Título del Proyecto]
# [Nombres de estudiantes] — [Fecha]
#
# Este notebook resume la evaluación del informe frente a la rúbrica proporcionada.

# %% [markdown]
# ## Resumen
# - Puntaje total obtenido: ___ / 130 puntos
# - Porcentaje: ___%
# - Equivalente escala (90 pts = 100%): ___ / 90

# %% [markdown]
# ## 1) Título y Abstract (máx. 10 pts) — ___ / 10
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 2) Introducción y Planteamiento (máx. 20 pts) — ___ / 20
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 3) Marco Teórico (máx. 20 pts) — ___ / 20
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 4) Implementación del Código (máx. 25 pts) — ___ / 25
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 5) Análisis y Resultados (máx. 30 pts) — ___ / 30
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 6) Discusión y Conclusiones (máx. 15 pts) — ___ / 15
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %% [markdown]
# ## 7) Presentación y Calidad General (máx. 10 pts) — ___ / 10
#
# **Observaciones:**
# -
#
# **Recomendación:**
# -

# %%
# Cálculo automático de totales
scores = {
    'Titulo_Abstract': (0, 10),
    'Introduccion': (0, 20),
    'Marco_Teorico': (0, 20),
    'Implementacion_Codigo': (0, 25),
    'Analisis_Resultados': (0, 30),
    'Discusion_Conclusiones': (0, 15),
    'Presentacion_Calidad': (0, 10)
}

total = sum(v[0] for v in scores.values())
max_total = sum(v[1] for v in scores.values())
pct = 100 * total / max_total if max_total > 0 else 0
scaled_90 = total / max_total * 90 if max_total > 0 else 0

print(f"Puntaje total: {total} / {max_total}")
print(f"Porcentaje: {pct:.2f}%")
print(f"Equivalente escala (90=100%): {scaled_90:.2f} / 90")

# %% [markdown]
# ## Resumen de Recomendaciones Principales
#
# 1.
# 2.
# 3.
# 4.
# 5.
#
# ---
#
# **Próximos pasos sugeridos:**
# -
