# %% [markdown]
# # 📝 Planificación del Proyecto de Investigación
#
# **Este notebook te guiará paso a paso en la planificación de tu proyecto.**
#
# Completa todas las secciones ANTES de comenzar a escribir el informe final. Este documento te ayudará a:
# - Elegir un modelo adecuado
# - Diseñar una pregunta de investigación sólida
# - Organizar el trabajo en equipo
# - Establecer un cronograma realista
#
# ---

# %% [markdown]
# ## 👥 PARTE 1: INFORMACIÓN DEL EQUIPO
#
# ### Integrantes del equipo
#
# **Miembro 1:**
# Nombre:  Matias Concha
# Fortalezas: Creatividad, buen manejo de la tecnología.
#
# **Miembro 2:**
# Nombre:  Diego Carrizo
# Fortalezas: Persistente, carismatico, comprensivo y buenas ideas.
#
# **Miembro 3:**
# Nombre:  Diego García
# Fortalezas: Inteligente, buen amigo, colaborador.
#
# **Miembro 4:**
# Nombre: Gabriel Calderón
# Fortalezas: Buen uso del computador, iniciativa.
#
# ---
#
# ### Medio de comunicación del equipo
#
# ¿Cómo se comunicarán? (WhatsApp, Discord, Email, etc.): Instagram.
#
# ¿Cuándo se reunirán? (días y horarios): Videollamada, google meets.
#
# ---

# %% [markdown]
# ## 🎯 PARTE 2: ELECCIÓN DEL MODELO
#
# ### 2.1 Modelos que ya conocemos
#
# **Mapa Logístico** (el que estudiamos en clases):
# $$x_{n+1} = r x_n (1 - x_n)$$
#
# - ✅ **Ventajas:** Ya lo conocemos, hay mucho material disponible, fácil de programar
# - ⚠️ **Desafío:** Será el más elegido, necesitas un enfoque original
# - 💡 **Ideas para diferenciarte:**
#   - Aplicarlo a un caso real específico con datos (ej: población de una especie local)
#   - Comparar con el modelo retardado (delayed logistic map)
#   - Analizar efectos de perturbaciones o ruido
#   - Estudiar mapas logísticos acoplados (dos poblaciones interactuando)
#
# **Mapa Logístico Retardado** (delayed logistic map):
# $$x_{n+1} = r x_n (1 - x_{n-\tau})$$
#
# - ✅ **Ventajas:** Más realista (considera historia pasada), menos conocido
# - ⚠️ **Desafío:** Un poco más complejo de programar
# - 💡 **Aplicaciones:** Poblaciones con tiempo de gestación, efectos de memoria en ecosistemas
#
# **Significado de parámetros:**
# - $x_n$: población en la generación actual
# - $x_{n-\tau}$: población $\tau$ generaciones en el pasado (memoria/retardo)
# - $r$: tasa de crecimiento
# - $\tau$: tiempo de retardo (ej: $\tau=1$ significa que la competencia depende de la población anterior)
#
# ---
#
# ### 2.2 Modelos nuevos SIN exponenciales (más accesibles)
#
# #### **OPCIÓN A: Modelo de Beverton-Holt** (Recursos Renovables)
# $$N_{n+1} = \frac{R N_n}{1 + (R-1)N_n/K}$$
#
# **¿Por qué elegirlo?**
# - Establece un equilibrio poblacional
# - Más fácil de analizar que el logístico
# - Aplicable a bosques, reforestación, recursos sostenibles
#
# **¿Es difícil?**
# - 🟢 Muy fácil de programar
# - 🟢 Comportamiento menos caótico
# - 🟡 Menos material disponible que el logístico
#
# **Significado de parámetros:**
# - $N_n$: tamaño de la población en la generación $n$
# - $R$: tasa de reproducción neta (número promedio de descendientes por individuo)
# - $K$: capacidad de carga (población máxima que el ambiente puede sostener)
# - **Característica:** Siempre converge a equilibrio estable (no hay caos)
#
# **Pregunta de investigación ejemplo:**
# > "¿Es sostenible el plan de reforestación de bosque nativo en la Región de Valparaíso según el modelo de Beverton-Holt?"
#
# ---
#
# #### **OPCIÓN B: Modelo SIR Discreto** (Epidemias)
# $$S_{n+1} = S_n - \beta S_n I_n$$
# $$I_{n+1} = I_n + \beta S_n I_n - \gamma I_n$$
# $$R_{n+1} = R_n + \gamma I_n$$
#
# **¿Por qué elegirlo?**
# - Súper relevante (COVID-19, gripe, sarampión)
# - Datos disponibles de OMS, MINSAL
# - Fácil de explicar (Susceptibles → Infectados → Recuperados)
# - Tras la pandemia, mucha gente está interesada en epidemiología
#
# **¿Es difícil?**
# - 🟡 Tres ecuaciones en vez de una (pero son lineales)
# - 🟢 Muy intuitivo de entender
# - 🟢 Mucho material educativo disponible
#
# **Significado de parámetros:**
# - $S_n$: número de personas **S**usceptibles (pueden contagiarse)
# - $I_n$: número de personas **I**nfectadas (contagian a otros)
# - $R_n$: número de personas **R**ecuperadas (inmunes, no contagian)
# - $\beta$: tasa de contacto/contagio (probabilidad de transmisión por contacto)
# - $\gamma$: tasa de recuperación (fracción que se recupera por día/semana)
# - **Nota:** $S_n + I_n + R_n = N$ (población total constante)
#
# **Pregunta de investigación ejemplo:**
# > "¿Cómo varía la curva de contagios de gripe estacional según la tasa de vacunación de la población escolar?"
#
# ---
#
# #### **OPCIÓN C: Modelo de Hassell** (Competencia por Recursos)
# $$N_{n+1} = \frac{\lambda N_n}{(1 + a N_n)^b}$$
#
# **¿Por qué elegirlo?**
# - Modela poblaciones con agregación espacial (animales en colonias)
# - Más general que el logístico (tiene un parámetro extra $b$)
# - Aplicable a insectos sociales, aves coloniales, lobos marinos
# - Permite estudiar diferentes tipos de competencia
#
# **¿Es difícil?**
# - 🟢 Fácil de programar (una sola ecuación)
# - 🟡 Necesitas entender qué representa el parámetro $b$
# - 🟢 Comportamiento rico y visual
#
# **Significado de parámetros:**
# - $\lambda$: tasa de reproducción
# - $a$: intensidad de la competencia
# - $b$: grado de agregación (b=1 es similar al logístico, b>1 es agregación fuerte)
#
# **Pregunta de investigación ejemplo:**
# > "¿Cómo afecta el grado de agregación espacial ($b$) a la estabilidad de colonias de lobos marinos en la costa chilena?"
#
# ---
#
# #### **OPCIÓN D: Modelo de Tent Map** (Caos Determinista)
# $$x_{n+1} = \begin{cases}
# \mu x_n & \text{si } x_n < 0.5 \\
# \mu (1 - x_n) & \text{si } x_n \geq 0.5
# \end{cases}$$
#
# **¿Por qué elegirlo?**
# - MUY fácil de entender (función lineal por partes)
# - Muestra caos "puro" (más simple que el logístico)
# - Excelente para estudiar sensibilidad a condiciones iniciales
# - Útil para demostrar el "efecto mariposa"
#
# **¿Es difícil?**
# - 🟢 SUPER fácil de programar (solo un if/else)
# - 🟢 Geometría muy visual (gráfico de telaraña)
# - 🟢 Fácil de analizar matemáticamente
#
# **Significado de parámetros:**
# - $x_n$: estado del sistema en el paso $n$ (normalizado entre 0 y 1)
# - $\mu$: parámetro de control (típicamente $0 < \mu \leq 2$)
# - Para $\mu = 2$: caos completamente desarrollado
# - **Forma de "carpa":** sube linealmente hasta 0.5, luego baja linealmente
#
# **Pregunta de investigación ejemplo:**
# > "¿Cómo cambia el tiempo de predictibilidad del tent map cuando duplicamos la precisión de las condiciones iniciales?"
#
# **Aplicaciones:**
# - Modelos simplificados de turbulencia
# - Criptografía y generación de números pseudoaleatorios
# - Demostración educativa del caos
#
# ---
#
# #### **OPCIÓN E: Modelo Depredador-Presa Discreto** (Lotka-Volterra Discreto)
# $$H_{n+1} = H_n + r H_n (1 - H_n/K) - a H_n P_n$$
# $$P_{n+1} = P_n + b a H_n P_n - m P_n$$
#
# **¿Por qué elegirlo?**
# - Clásico de la ecología (presas y depredadores)
# - Muy visual (ciclos poblacionales)
# - Datos disponibles (linces y liebres, zorros y conejos)
# - Relevante para conservación de especies
#
# **¿Es difícil?**
# - 🟡 Dos ecuaciones
# - 🟢 Fácil de explicar (presas crecen, depredadores comen)
# - 🟢 Gráficos de fase muy bonitos
#
# **Significado de parámetros:**
# - $H_n$: población de presas (herbívoros)
# - $P_n$: población de depredadores
# - $r$: tasa de crecimiento de presas
# - $a$: tasa de captura
# - $b$: eficiencia de conversión (presas → depredadores)
# - $m$: tasa de mortalidad de depredadores
#
# **Pregunta de investigación ejemplo:**
# > "¿Puede el modelo Lotka-Volterra discreto explicar las oscilaciones de 10 años en las poblaciones de linces y liebres en Canadá?"
#
# ---
#
# #### **OPCIÓN F: Modelo de Crecimiento con Efecto Allee**
# $$N_{n+1} = N_n + r N_n \left(1 - \frac{N_n}{K}\right) \left(\frac{N_n}{A} - 1\right)$$
#
# **¿Por qué elegirlo?**
# - Modela extinción por población MUY pequeña (efecto Allee)
# - Crucial para especies en peligro de extinción
# - Tres resultados posibles: extinción, crecimiento, o equilibrio
# - Muy relevante para conservación
#
# **¿Es difícil?**
# - 🟢 Una ecuación (más compleja que el logístico, pero entendible)
# - 🟡 Necesitas entender el concepto de "umbral de extinción"
# - 🟢 Aplicaciones muy claras a conservación
#
# **¿Qué es el efecto Allee?**
# Cuando una población es muy pequeña, tiene problemas para:
# - Encontrar pareja
# - Defenderse de depredadores
# - Mantener diversidad genética
#
# **Significado de parámetros:**
# - $A$: umbral de Allee (población mínima viable)
# - $K$: capacidad de carga
# - $r$: tasa de crecimiento
#
# **Pregunta de investigación ejemplo:**
# > "¿Cuál es el tamaño mínimo viable de una población de huemul para evitar la extinción según el modelo con efecto Allee?"
#
# **Aplicaciones:**
# - Huemul, cóndor, pudú (especies chilenas en peligro)
# - Reintroducción de especies
# - Planificación de áreas protegidas
#
# ---
#
# ### 2.3 Modelos CON exponenciales (requieren más matemática)
#
# ⚠️ **Estos modelos usan la función exponencial $e^x$. Si no la has visto aún, puedes usar uno de los modelos de arriba.**
#
# #### **OPCIÓN G: Modelo de Ricker** (Pesca)
# $$N_{n+1} = N_n e^{r(1 - N_n/K)}$$
#
# **¿Por qué elegirlo?**
# - Muy usado en gestión pesquera REAL
# - Datos disponibles de pesca en Chile (FAO, SUBPESCA)
# - Relevante para la sostenibilidad y cambio climático
# - Similar al logístico pero con comportamiento diferente
#
# **¿Es difícil?**
# - 🟢 Fácil de programar (casi igual que el logístico)
# - 🟡 Necesitas entender la función exponencial
# - 🟢 Mucha literatura disponible
#
# **Significado de parámetros:**
# - $N_n$: tamaño de la población (número de peces) en la generación $n$
# - $r$: tasa intrínseca de crecimiento (reproducción - mortalidad natural)
# - $K$: capacidad de carga del ambiente (población máxima sostenible)
# - $e$: número de Euler (≈2.718), base de la función exponencial
#
# **Pregunta de investigación ejemplo:**
# > "¿Puede el modelo de Ricker predecir el colapso de la población de sardinas en la costa chilena basándose en datos históricos de captura?"
#
# ---
#
# #### **OPCIÓN H: Modelo de Nicholson-Bailey** (Control de Plagas)
# $$H_{n+1} = \lambda H_n e^{-aP_n}$$
# $$P_{n+1} = c H_n (1 - e^{-aP_n})$$
#
# **¿Por qué elegirlo?**
# - Dos especies interactuando (hospedador y parásito)
# - Aplicable a control biológico de plagas en agricultura
# - Muy visual (oscilaciones entre poblaciones)
# - Original y práctico
#
# **¿Es difícil?**
# - 🟡 Dos ecuaciones acopladas
# - 🟡 Necesitas entender interacciones entre especies
# - 🟢 Gráficos muy interesantes
#
# **Significado de parámetros:**
# - $H_n$: población de **H**ospedadores (ej: insectos plaga)
# - $P_n$: población de **P**arásitos/parasitoides (enemigos naturales)
# - $\lambda$: tasa de reproducción de hospedadores (sin parásitos)
# - $a$: tasa de búsqueda/ataque del parásito (eficiencia del control)
# - $c$: número de parásitos emergentes por hospedador parasitado
# - $e^{-aP_n}$: probabilidad de que un hospedador escape del parasitismo
#
# **Pregunta de investigación ejemplo:**
# > "¿Puede un parásito natural controlar la plaga de polilla del tomate sin necesidad de pesticidas químicos?"
#
# ---
#
# ### 2.4 Tu elección
#
# **Modelo que elegimos:**
# Mapa logístico
#
# **¿Por qué lo elegimos?**
# Porque ya lo vimos en clase
#
# **¿Qué nos preocupa de este modelo?**
# Su funcionalidad.
#
# **¿Cómo vamos a aprender sobre él?** (videos, papers, tutoriales, consultar al profesor)
# Ocupando las guias anteriores si es que el profe nos da acceso a ellas
#
#
# ---

# %% [markdown]
# ## 🔬 PARTE 3: DISEÑANDO LA PREGUNTA DE INVESTIGACIÓN
#
# ### 3.1 ¿Qué hace una BUENA pregunta de investigación?
#
# Una buena pregunta debe ser:
#
# ✅ **Específica:** No "¿Cómo funciona el modelo?", sino "¿Qué valores de $r$ producen comportamiento caótico?"
#
# ✅ **Testeable:** Debes poder responderla con simulaciones o datos
#
# ✅ **Relevante:** Debe tener conexión con un problema real
#
# ✅ **Alcanzable:** Puedes responderla en el tiempo disponible
#
# ❌ **Demasiado amplia:** "¿Cómo afecta el caos a las poblaciones?" (muy general)
#
# ❌ **Demasiado simple:** "¿Qué es el mapa logístico?" (solo descriptiva)
#
# ❌ **No testeable:** "¿Por qué existe el caos en la naturaleza?" (filosófica)
#
# ---
#
# ### 3.2 Plantilla para diseñar tu pregunta
#
# Completa esta plantilla:
#
# **1. ¿Qué fenómeno del mundo real te interesa?**
# (ej: colapso pesquero, epidemias, extinción de especies, plagas agrícolas)
# plagas agricolas
#
#
# **2. ¿Qué aspecto específico quieres estudiar?**
# (ej: el efecto de la sobrepesca, la efectividad de vacunas, el umbral de extinción)
# la polilla del racimo de la vid y su efecto en el valle del maule
#
# **3. ¿Qué parámetro o condición vas a variar?**
# (ej: tasa de crecimiento, tasa de contacto, condiciones iniciales)
# su tasa de crecimiento, y la vamos a poner a prueba bajo los efectos de los plagicidas.
#
# **4. ¿Qué esperas observar o comparar?**
# (ej: transición a caos, oscilaciones, convergencia a equilibrio, comparación con datos reales)
# Queremos observar la poblacion de la polilla de la vid.
#
#
# **5. Ahora junta todo en UNA pregunta:**
# ¿Cómo podemos relacionar el crecimiento y reproduccion de la polilla de la vid en las viñas del valle del maule?
# ¿Qué efectos tendría la aplicación de plagicidas en la especie invasora?
#
# ---
#
# ### 3.3 Ejemplos de preguntas BUENAS vs MALAS
#
# #### Para el Mapa Logístico:
#
# ❌ MALA: "¿Cómo funciona el mapa logístico?"
# - Problema: Demasiado general, solo descriptiva
#
# ✅ BUENA: "¿A partir de qué valor de $r$ el mapa logístico presenta comportamiento caótico, y coincide este valor con los ciclos irregulares observados en poblaciones de *Drosophila*?"
# - Por qué es buena: Específica, testeable, compara teoría con datos reales
#
# #### Para el Modelo de Ricker:
#
# ❌ MALA: "¿Por qué colapsan las poblaciones de peces?"
# - Problema: Muy amplia, muchos factores no relacionados con el modelo
#
# ✅ BUENA: "¿Puede el modelo de Ricker predecir el punto de colapso de la población de sardina común (*Strangomera bentincki*) en base a las tasas de captura de los últimos 20 años?"
# - Por qué es buena: Específica, usa datos reales, testeable
#
# #### Para el Modelo SIR:
#
# ❌ MALA: "¿Cómo se propagan las enfermedades?"
# - Problema: Demasiado general
#
# ✅ BUENA: "¿Qué porcentaje de la población escolar debe vacunarse contra la gripe para prevenir una epidemia según el modelo SIR discreto?"
# - Por qué es buena: Específica, práctica, responde una pregunta de política pública
#
# ---
#
# ### 3.4 Valida tu pregunta
#
# Responde SÍ o NO:
#
# - [Si ] ¿Es específica? (no vaga)
# - [Si ] ¿Puedes responderla con simulaciones o datos?
# - [Si ] ¿Tiene relevancia práctica o aplicación real?
# - [Si ] ¿Puedes responderla en el tiempo disponible?
# - [Si ] ¿Va más allá de solo describir el modelo?
#
# Si respondiste SÍ a todas, ¡tienes una buena pregunta! Si no, revisa y ajusta.
#
# ---

# %% [markdown]
# ## 💡 PARTE 4: FORMULANDO LA HIPÓTESIS
#
# ### 4.1 ¿Qué es una hipótesis?
#
# Una hipótesis es tu **predicción** de lo que crees que vas a encontrar. Debe ser:
# - Clara y específica
# - Testeable con tus simulaciones
# - Basada en algún razonamiento o información previa
#
# ### 4.2 Plantilla para tu hipótesis
#
# Completa: Se espera que cuando el especie se nivele el r sea de 3.1, trras la aplicacion del plagicida el r bajaría drásticamente, dependiendo de la calidad del plagicida aplicado
#
# "Se espera que cuando [CONDICIÓN/PARÁMETRO] sea [VALOR/RANGO], el modelo mostrará [COMPORTAMIENTO ESPERADO], lo cual [CONSECUENCIA O IMPLICACIÓN REAL]."
#
# **Ejemplo (Mapa Logístico):**
# > "Se espera que cuando $r > 3.57$, el modelo logístico muestre comportamiento caótico con fluctuaciones impredecibles, lo cual explicaría las variaciones erráticas observadas en las poblaciones de insectos en ambientes inestables."
#
# **Ejemplo (Ricker):**
# > "Se espera que cuando la tasa de captura supere el 40% de la población anual, el modelo de Ricker prediga un colapso poblacional en menos de 10 años, lo cual coincidiría con el colapso histórico de la sardina española en 2012."
#
# **Ejemplo (SIR):**
# > "Se espera que cuando más del 70% de la población esté vacunada, el modelo SIR prediga que no ocurrirá una epidemia incluso con casos iniciales de infección, lo cual justificaría las políticas de vacunación masiva."
#
# ---
#
# ### 4.3 Tu hipótesis
#
# **Escribe aquí tu hipótesis:**
# La polilla bajará su ratio de reproducción (r), tras la aplicación del insecticida Clorpifiros en el valle del maule.
#
#
# **¿En qué basas esta predicción?** (intuición, estudios previos, observaciones):
# Se basa en los estudios del sag sobre"Lobresia botana", y su estudio sobre el plagicida "Clorpifiros".
#
# ---

# %% [markdown]
# ## 📊 PARTE 5: FUENTES DE DATOS (si aplica)
#
# ### 5.1 ¿Vas a usar datos reales o solo simulaciones?
#
# **Opción elegida:** (marca con X)
#
# - [ ] Solo simulaciones (exploración teórica del modelo)
# - [X ] Simulaciones + datos reales (comparación)
# - [ ] Ajuste del modelo a datos reales (estimación de parámetros)
#
# ---
#
# ### 5.2 Si usarás datos reales, ¿de dónde los obtendrás?
#
# **Fuentes posibles según el modelo:**
#
# #### Para modelos de poblaciones/pesca:
# - **FAO Fisheries:** http://www.fao.org/fishery/statistics/en
# - **SUBPESCA (Chile):** http://www.subpesca.cl/portal/616/w3-propertyvalue-50448.html
# - **SERNAPESCA:** http://www.sernapesca.cl/estadisticas
# - **Global Fishing Watch:** https://globalfishingwatch.org/data/
#
# #### Para modelos epidemiológicos:
# - **OMS (WHO):** https://www.who.int/data
# - **MINSAL Chile:** https://www.minsal.cl/datos-abiertos/
# - **CDC:** https://www.cdc.gov/datastatistics/index.html
# - **Our World in Data:** https://ourworldindata.org/
#
# #### Para modelos ecológicos/forestales:
# - **CONAF:** https://www.conaf.cl/
# - **Global Forest Watch:** https://www.globalforestwatch.org/
#
# #### Datos generales:
# - **Kaggle Datasets:** https://www.kaggle.com/datasets
# - **Data.gov:** https://data.gov/
# - **Google Dataset Search:** https://datasetsearch.research.google.com/
#
# ---
#
# ### 5.3 Tus fuentes de datos
#
# **Fuente 1:**
# URL o referencia:
# ¿Qué datos específicos usarás?:  SAG, ODEPA y MINAGRI
#
# **Fuente 2:**
# URL o referencia:
# ¿Qué datos específicos usarás?:  https://www.sag.cl/noticias/sag-realiza-estudio-de-la-dinamica-poblacional-de-la-lobesia-botrana-para-mejorar-control-en-predios-agricolas
#
# **Formato de los datos:** (CSV, Excel, PDF, etc.)  Pdf
#
# **¿Necesitas procesar o limpiar los datos?** ¿Cómo?
#
#
# ---

# %% [markdown]
# ## 👷 PARTE 6: DISTRIBUCIÓN DE RESPONSABILIDADES
#
# ### 6.1 Tareas principales del proyecto
#
# | Tarea | Responsable(s) | Fecha límite | Estado |
# |-------|---------------|--------------|--------|
# | Investigación bibliográfica (buscar papers, videos) |08-11 | | x |
# | Búsqueda y descarga de datos reales (si aplica) |- | | - |
# | Implementación del modelo en Python/otro |15-11 | | x |
# | Generación de gráficos y simulaciones |15-11 | | x |
# | Análisis de resultados |15-08 | | x |
# | Redacción de Introducción y Marco Teórico |15-08 | | x |
# | Redacción de Metodología y Resultados | | | ⬜ |
# | Redacción de Discusión y Conclusiones | | | ⬜ |
# | Revisión de ortografía y formato | | | ⬜ |
# | Preparación de presentación oral (si aplica) | | | ⬜ |
#
# ---
#
# ### 6.2 Acuerdos del equipo
#
# **¿Qué hacemos si alguien no cumple con su parte?**  Conversamos con él
#
#
# **¿Cómo tomaremos decisiones importantes?** (por votación, consenso, líder designado)  Votacion
#
#
# **¿Con qué frecuencia revisaremos el progreso?** (diario, 2 veces por semana, etc.)  Por semana
#
#
# ---

# %% [markdown]
# ## 📅 PARTE 7: CRONOGRAMA
#
# ### 7.1 Timeline del proyecto
#
# Completa con fechas reales:
#
# | Hito | Fecha objetivo | Completado |
# |------|---------------|------------|
# | Completar este notebook de planificación |08-11 | x |
# | Aprender sobre el modelo elegido |08-11 | x |
# | Obtener/generar datos |08-11 | x |
# | Implementar modelo funcional |15-11 | x |
# | Tener al menos 3 gráficos |15-11 | x |
# | Borrador de Introducción y Marco Teórico |15-11 | x |
# | Borrador de Metodología y Resultados | | ⬜ |
# | Borrador de Discusión y Conclusiones | | ⬜ |
# | Revisión completa del informe | | ⬜ |
# | **ENTREGA FINAL** | | ⬜ |
#
# ---
#
# ### 7.2 Plan semanal
#
# **Semana 1:**
# Objetivos:
# Tareas específicas:  Comprender el objetivo, definir tareas, preparar hipotesis, resolver preguntas basicas y comprender el tema a tratar
#
# **Semana 2:**
# Objetivos:
# Tareas específicas:  Empezar con estadisticas reales, primeros graficos tablas comparativas, etc.
#
# **Semana 3:**
# Objetivos:  --
# Tareas específicas:  Terminar detalles, resolver dudasa, aprender información, desarrollar la parte mas laboriosa.
#
# **Semana 4 (entrega):**
# Objetivos:  --
# Tareas específicas:  Terminar la presentación
#
# ---

# %% [markdown]
# ## 🎯 PARTE 8: RECURSOS DE APRENDIZAJE
#
# ### 8.1 Para aprender sobre tu modelo
#
# **Videos recomendados:**
# - Veritasium (YouTube): "This equation will change how you see the world" (Mapa Logístico)
# - 3Blue1Brown: Videos sobre caos y dinámica no lineal
# - Khan Academy: Modelos de población
#
# **Páginas web interactivas:**
# - https://www.complexity-explorables.org/ (exploraciones interactivas)
# - https://www.geogebra.org/ (simulaciones visuales)
#
# **Papers accesibles:**
# - May, R. M. (1976). "Simple mathematical models with very complicated dynamics." Nature.
# - Buscar en Google Scholar: "[tu modelo] educational introduction"
#
# ---
#
# ### 8.2 Para programación
#
# **Si no sabes programar:**
# - Usa el código de ejemplo del notebook principal como plantilla
# - Tutorial de Python básico: https://www.learnpython.org/
# - W3Schools Python: https://www.w3schools.com/python/
#
# **Si sabes programar:**
# - Documentación NumPy: https://numpy.org/doc/
# - Matplotlib gallery: https://matplotlib.org/stable/gallery/index.html
# - SciPy para análisis avanzado: https://docs.scipy.org/
#
# **Alternativas a Python:**
# - GeoGebra (visual, sin código)
# - Excel/Google Sheets (para modelos simples)
# - MATLAB/Octave
# - Wolfram Alpha/Mathematica
#
# ---
#
# ### 8.3 Recursos que encontramos útiles
#
# Lista aquí los recursos que vayas descubriendo:
#
# 1. Mimo: Aprender a progamar rápidamente
# 2. Knowunity: IA del estudio, planes de estudio, pequeñas clases de programación
# 3. Left Peel: Canal de YouTube con videos rápidos con tips sobre la creacion de graficos en python
#
# ---

# %% [markdown]
# ## ✅ CHECKLIST FINAL DE PLANIFICACIÓN
#
# Antes de empezar el informe, verifica que tengas:
#
# ### Equipo y organización
# - [x ] Todos los integrantes identificados con sus fortalezas
# - [x ] Medio de comunicación establecido
# - [x ] Horarios de reunión definidos
# - [x ] Responsabilidades distribuidas claramente
#
# ### Investigación
# - [x ] Modelo elegido y justificado
# - [x ] Pregunta de investigación específica y testeable
# - [x ] Hipótesis clara y razonable
# - [x ] Fuentes de datos identificadas (si aplica)
# - [x ] Al menos 3 recursos de aprendizaje encontrados
#
# ### Planificación
# - [x ] Cronograma con fechas específicas
# - [x ] Plan semanal definido
# - [x ] Acuerdos de equipo establecidos
# - [mas o menos ] Criterios de evaluación revisados
#
# ---
#
# ## 🚀 PRÓXIMOS PASOS
#
# Una vez completado este notebook:
#
# 1. **Guarda este documento** (será parte de tu entrega)
# 2. **Comparte con tu equipo** y asegúrate de que todos estén de acuerdo
# 3. **Muestra al profesor** para recibir retroalimentación temprana
# 4. **Comienza a trabajar** en el notebook principal: `PROYECTO_INVESTIGACION_NOVIEMBRE.ipynb`
#
# **¡Recuerda:** Una buena planificación es la mitad del éxito! 🎯
#
# ---
#
# ## 💬 ESPACIO PARA NOTAS
#
# Usa este espacio para anotar ideas, preguntas, o cosas que discutir con el profesor:
