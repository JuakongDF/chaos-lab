# %% [markdown]
# # EVALUACIÓN: Reproducción de la Polilla de la Vid con Plaguicidas
# Diego Carrizo, Diego Garcia, Matias Concha, Gabriel Calderón — 21 Noviembre 2025
#
# Este notebook resume la evaluación del informe frente a la rúbrica proporcionada.

# %% [markdown]
# ## Resumen
# - **Puntaje total obtenido: 72 puntos**
# - **Porcentaje: 82%**
# El archivo `informe.ipynb` presenta una mejora significativa, integrando pregunta de investigación, hipótesis, marco teórico, análisis, discusión y conclusiones en un documento narrativo cohesivo. Separadamente, incluyen código y gráficos.

# %% [markdown]
# ## 1) Título y Abstract (máx. 10 pts) — 7 / 10
#
# **Observaciones (informe.ipynb):**
# - ✅ Título claro: "Polilla de la Vid: Reproducción"
# - ✅ Tiene introducción narrativa que funciona como abstract descriptivo
# - ✅ Menciona el contexto (economía vitivinícola chilena), el problema (plaga), y el método (mapa logístico)
# - ✅ Resume resultados principales (plaguicida B efectivo, A inefectivo)
# - ⚠️ No está en formato de abstract científico formal (150-250 palabras en un bloque estructurado)
# - ⚠️ Falta indicar autores al inicio del documento
#
# **Recomendación:**
# - Crear un abstract formal de 150-200 palabras después del título con estructura: Contexto → Pregunta → Método → Resultados → Conclusión
# - Agregar nombres de autores debajo del título (actualmente están al final)

# %% [markdown]
# ## 2) Introducción y Planteamiento (máx. 20 pts) — 20 / 20
#
# **Observaciones (informe.ipynb):**
# - ✅ **Excelente contexto y motivación:** Explican la importancia de la polilla de la vid para la economía chilena (producción de vinos), mencionan la zona central y viñedos
# - ✅ **Pregunta de investigación clara:** "¿Cómo se ve afectado el crecimiento poblacional de la polilla de la vid tras la aplicación de distintos plaguicidas?"
# - ✅ **Hipótesis explícita:** "Depende de la eficiencia del plaguicida. No serviría de nada aplicar un plaguicida de baja eficiencia"
# - ✅ Mencionan el objetivo: predecir el comportamiento de la plaga con plaguicidas
#
# **Recomendación:**
# - Ampliar con 1-2 párrafos más sobre el impacto de *Lobesia botrana* (datos del SAG)
# - Mencionar estudios previos o estadísticas de pérdidas en viñedos chilenos

# %% [markdown]
# ## 3) Marco Teórico (máx. 20 pts) — 15 / 20
#
# **Observaciones (informe.ipynb):**
# - ✅ **Presenta el mapa logístico:** Mencionan la ecuación (aunque no en formato LaTeX)
# - ✅ **Explica parámetros claramente:**
#   - Xn+1 = próxima generación
#   - r = tasa de reproducción (depende del plaguicida)
#   - Xn = generación actual
#   - (1-Xn) = restricción ambiental/alimento disponible
# - ✅ **Justifica el modelo:** Explica que permite modelar crecimiento en entorno controlado (viña) con alimento fijo
# - ✅ **Tiene 3 referencias:** Enlaces del SAG sobre Lobesia botrana, plaguicidas autorizados, y control en predios
# - ⚠️ Falta explicación más profunda de cómo el plaguicida modifica el valor de r
# - ⚠️ No menciona literatura académica sobre el mapa logístico
#
# **Recomendación:**
# - Explicar explícitamente: "Un plaguicida con eficiencia del 95% reduce r de [valor base] a [valor reducido]"
# - Agregar 1-2 referencias académicas sobre dinámica poblacional o control de plagas

# %% [markdown]
# ## 4) Implementación del Código (máx. 25 pts) — 20 / 25
#
# **Observaciones:**
# - El archivo `graph (2).ipynb` contiene código funcional que simula correctamente el mapa logístico.
# - El código está bien comentado en español y usa nombres descriptivos de variables.
# - La simulación compara escenarios con y sin plaguicidas (diferentes valores de r).
# - El código NO está integrado en el documento principal de informe.
# - Falta modularidad: no hay funciones reutilizables claramente definidas para análisis paramétrico.
#
# **Recomendación:**
# - Copiar el código de `graph (2).ipynb` al notebook principal del informe en la sección correspondiente.
# - Crear funciones modulares (ej: `simular_con_plaguicida(eficacia, generaciones)`) para facilitar experimentos.

# %% [markdown]
# ## 5) Análisis y Resultados (máx. 30 pts) — 18 / 30
#
# **Observaciones (informe.ipynb):**
# - ✅ **Análisis narrativo detallado:** Describen los resultados de 3 escenarios:
#   - Sin plaguicidas: "la plaga se disparó y creció rápidamente"
#   - Plaguicida A (50%): "resultó horripilante, eliminó solo 50%, impacto inicial pero después insignificante"
#   - Plaguicida B (95%): "mantuvo a raya la población, aniquilando las polillas después de 3 generaciones"
# - ✅ **Interpretación cuantitativa:** Mencionan población inicial (100 polillas), número de generaciones (3), eficiencias específicas (50%, 95%)
# - ✅ **Contexto aplicado:** Mencionan que hay 3 picos de crecimiento por temporada (dato real de la especie)
# - ✅ **Confirman hipótesis:** "plaguicida con mayor eficiencia aniquiló la plaga rápidamente"
# - ⚠️ Dicen que crearon el gráfico en Python y lo adjuntan "al final del documento" pero **no está visible en informe.ipynb**
# - ❌ No hay gráfico embebido en el documento
# - ❌ Falta exploración de valores intermedios de eficiencia
#
# **Recomendación:**
# - **URGENTE:** Insertar el código y gráficos de `graph (2).ipynb` en el `informe.ipynb` (tienen el código funcional, solo falta copiarlo)
# - Agregar gráfico de bifurcaciones o sensibilidad paramétrica
# - Crear tabla con valores numéricos (generaciones, población final por escenario)

# %% [markdown]
# ## 6) Discusión y Conclusiones (máx. 15 pts) — 10 / 15
#
# **Observaciones (informe.ipynb):**
# - ✅ **Discusión presente:** Mencionan que hay 3 picos de crecimiento por temporada (contexto biológico real) y que esto es importante para timing de aplicación
# - ✅ **Confirma hipótesis:** "Nuestra hipótesis se cumplió, el plaguicida con mayor eficiencia aniquiló la plaga"
# - ✅ **Conclusiones múltiples:**
#   1. Importancia de usar plaguicida de calidad (vs pérdida de producción)
#   2. Sensibilidad de la tasa de reproducción a pequeñas variaciones en r
#   3. Crecimiento puede ser rapidísimo o lento según pequeñas variaciones
#   4. Cuidado con efectos secundarios de plaguicidas (pueden empeorar cosecha)
#   5. Importancia de control de plagas para economía (posición de Chile en vinos)
# - ✅ **Conexión con aplicación real:** Mencionan que controlar plagas es importante para mantener la economía y posición como país productor de vinos
# - ⚠️ No discuten limitaciones del modelo explícitamente
# - ⚠️ No mencionan trabajo futuro o extensiones posibles
#
# **Recomendación:**
# - Agregar párrafo sobre limitaciones: "El modelo no considera resistencia a plaguicidas, factores climáticos, depredadores naturales"
# - Mencionar posibles extensiones: "Trabajo futuro podría incluir modelo estocástico o datos de campo reales"

# %% [markdown]
# ## 7) Presentación y Calidad General (máx. 10 pts) — 4 / 10
#
# **Observaciones (informe.ipynb):**
# - ✅ **Documento cohesivo:** Todo el contenido narrativo está en un solo archivo, siguiendo una estructura lógica
# - ✅ **Redacción clara:** El español es correcto, sin errores graves de ortografía, lenguaje accesible
# - ✅ **Flujo narrativo:** El documento cuenta una historia coherente desde motivación hasta conclusiones
# - ⚠️ **Problema de formato:** Todo está en una SOLA celda markdown gigante, sin organización visual en secciones
# - ⚠️ **Falta código:** Mencionan "adjuntamos al final de este documento" pero no hay celdas de código
# - ❌ **Sin títulos/subtítulos:** No usa encabezados `#`, `##` para marcar secciones (Introducción, Métodos, Resultados, etc.)
# - ❌ **Ecuaciones sin LaTeX:** La ecuación del mapa logístico no está en formato matemático
#
# **Recomendación:**
# - Separar el contenido en múltiples celdas markdown con encabezados claros
# - Agregar celdas de código del archivo `graph (2).ipynb` al final
# - Convertir ecuaciones a formato LaTeX: $x_{n+1} = r \cdot x_n \cdot (1 - x_n)$
# - Agregar encabezados: `# Introducción`, `## Mapa Logístico`, `# Análisis`, `# Conclusiones`

# %% [markdown]
# ## Resumen de Recomendaciones Principales
#
# ### 🎉 GRAN MEJORA: De 41 → 68 puntos (+27 puntos, +21%)
#
# El archivo **`informe.ipynb`** representa una **transformación completa** del trabajo:
#
# **Lo que ahora tienen ✅:**
# 1. ✅ **Introducción excelente** con contexto económico claro (vinos chilenos)
# 2. ✅ **Pregunta de investigación y hipótesis** integradas en el documento principal
# 3. ✅ **Marco teórico completo** con explicación del mapa logístico y sus parámetros
# 4. ✅ **Referencias relevantes** (3 enlaces del SAG sobre Lobesia botrana y plaguicidas)
# 5. ✅ **Análisis detallado** de 3 escenarios con interpretación cualitativa
# 6. ✅ **Discusión sustancial** conectando con biología real (3 picos por temporada)
# 7. ✅ **Conclusiones múltiples** (5 puntos concretos) sobre eficiencia, sensibilidad, economía
# 8. ✅ **Documento cohesivo** con flujo narrativo claro
#
# **Lo que aún falta ⚠️:**
# 1. ❌ **Código no integrado:** Dicen "adjuntamos al final" pero no hay celdas de código en `informe.ipynb`
#    - **Solución:** Copiar el código de `graph (2).ipynb` al final del informe
# 2. ❌ **Gráficos no visibles:** Mencionan el gráfico pero no está embebido
#    - **Solución:** Ejecutar las celdas de código y asegurar que los gráficos se muestren
# 3. ⚠️ **Formato de una sola celda:** Todo el texto está en una celda markdown gigante
#    - **Solución:** Separar en secciones con encabezados `#`, `##`
# 4. ⚠️ **Ecuaciones sin LaTeX:** La fórmula está en texto plano
#    - **Solución:** Escribir $x_{n+1} = r \cdot x_n \cdot (1 - x_n)$
#
# ---
#
# ### 📊 Comparación: Documento Original vs Nuevo
#
# | Sección | Original | Nuevo | Mejora |
# |---------|----------|-------|--------|
# | Título/Abstract | 4/10 | 7/10 | +3 pts |
# | Introducción | 8/20 | 16/20 | +8 pts |
# | Marco Teórico | 2/20 | 13/20 | +11 pts |
# | Código | 20/25 | 20/25 | 0 pts (funcional pero separado) |
# | Análisis | 8/30 | 18/30 | +10 pts |
# | Discusión | 0/15 | 10/15 | +10 pts |
# | Presentación | 4/10 | 4/10 | 0 pts (sigue siendo una celda) |
# | **TOTAL** | **41/130** | **68/130** | **+27 pts** |
#
# ---
#
# ### 🚀 Próximos pasos para llegar a ~85+ puntos:
#
# **PRIORIDAD 1 (puede recuperar +5-10 pts):**
# - Copiar el código de `graph (2).ipynb` al final de `informe.ipynb`
# - Asegurar que los gráficos se rendericen correctamente
# - Esto completará la sección de código/implementación
#
# **PRIORIDAD 2 (puede recuperar +3-5 pts):**
# - Separar el documento en múltiples celdas con títulos:
#   - `# Introducción`
#   - `## Contexto: La Polilla de la Vid`
#   - `## Pregunta de Investigación`
#   - `# Marco Teórico: Mapa Logístico`
#   - `# Metodología`
#   - `# Resultados`
#   - `# Discusión`
#   - `# Conclusiones`
#   - `# Referencias`
#
# **PRIORIDAD 3 (puede recuperar +2-3 pts):**
# - Convertir la ecuación a LaTeX
# - Agregar un abstract formal de 150-200 palabras al inicio
# - Mencionar limitaciones del modelo explícitamente
#
# **Puntaje actual: 68/130 (52.3%)**
# **Potencial con mejoras: 85-90/130 (65-69%)**
#
# ¡El trabajo ha mejorado significativamente! Con las mejoras de formato y código integrado, pueden alcanzar fácilmente 85+ puntos.
