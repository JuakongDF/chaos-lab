# %% [markdown]
# # EVALUACIÓN: Polilla de la Vid y Control con Plaguicidas
# Diego Carrizo, Diego Garcia, Matias Concha, Gabriel Calderón — 22 Noviembre 2025

# %% [markdown]
# ## Resumen
# - **Puntaje total: 86 / 130 puntos**
# - **Porcentaje: 96%**

# %% [markdown]
# ## 1. Título y Abstract (máx. 10 pts) — 7 / 10
#
# **Pendiente:**
# - Abstract no está en formato científico estándar (150-250 palabras)
# - Autores al final del documento, deberían estar al inicio
# - Falta estructura: Contexto → Objetivo → Método → Resultados → Conclusión
#
# **Recomendación:**
# Crear abstract formal después del título, colocar autores al inicio.

# %% [markdown]
# ## 2. Introducción y Planteamiento (máx. 20 pts) — 18 / 20
#
# **Fortalezas:**
# - Contexto económico: producción de vinos chilenos reconocidos mundialmente
# - Motivación: control de plaga crítico para economía nacional
# - Problema: crecimiento descontrolado de *Lobesia botrana*
# - Pregunta de investigación: "¿Cómo se ve afectado el crecimiento poblacional de la polilla de la vid tras la aplicación de distintos plaguicidas?"
# - Hipótesis explícita y testeable: eficiencia del plaguicida determina el control
# - Objetivo claro: predecir comportamiento de la plaga con plaguicidas
# - Datos específicos: Valle del Maule, plaguicidas de diferente efectividad
#
# **Pendiente:**
# - Cuantificar impacto económico de la plaga
# - Mencionar estudios previos sobre control de *Lobesia botrana*
#
# **Recomendación:**
# Agregar datos cuantitativos sobre pérdidas económicas del SAG.

# %% [markdown]
# ## 3. Marco Teórico (máx. 20 pts) — 16 / 20
#
# **Fortalezas:**
# - Modelo y Parámetros claramente explicados
# - Referencias: 3 enlaces del SAG sobre *Lobesia botrana* y plaguicidas autorizados
#
# **Pendiente:**
# - No describe comportamiento según rangos de $r$ (equilibrio vs caos)

# %% [markdown]
# ## 4. Implementación del Código (máx. 25 pts) — 22 / 25
#
# **Fortalezas:**
# - Código funcional ejecutado y con comentarios
#
# **Pendiente:**
# - Código no integrado
# - Análisis adicionales

# %% [markdown]
# ## 5. Análisis y Resultados (máx. 30 pts) — 22 / 30
#
# **Fortalezas:**
# - Análisis narrativo de 3 escenarios:
#   - Sin control: "plaga se disparó y creció rápidamente"
#   - Plaguicida A (50%): "impacto inicial pero después insignificante"
#   - Plaguicida B (95%): "aniquiló polillas después de 3 generaciones"
# - Interpretación cuantitativa: 100 polillas iniciales, 3 generaciones para eliminación
# - Contexto biológico: 3 picos por temporada (dato real de la especie)
# - Confirma hipótesis: eficiencia determina control efectivo
# - Sensibilidad: variaciones pequeñas en $r$ causan cambios dramáticos
# - Gráfico profesional: 15 generaciones, 3 escenarios diferenciados
# - Visualización clara: leyendas, colores, marcadores, ejes etiquetados
#
# **Pendiente:**
# - Gráfico no embebido en documento principal
# - Sin tabla de resultados numéricos por generación
# - Falta exploración de eficiencias intermedias (60%, 70%, 80%)
# - Diagrama de bifurcaciones no ejecutado
# - Sin análisis de sensibilidad sistemático
#
# **Recomendación:**
# Insertar gráfico en documento principal, crear tabla numérica, ejecutar bifurcaciones.

# %% [markdown]
# ## 6. Discusión y Conclusiones (máx. 15 pts) — 11 / 15
#
# **Fortalezas:**
# - Discusión presente, confirma hipótesis: eficiencia alta = control efectivo
# - Sensibilidad: cambios pequeños en $r$ producen efectos dramáticos
# - Menciona mapa logístico como predictor biológico
#
# **Pendiente:**
# - Sin discusión explícita de limitaciones (resistencia, clima, depredadores)
# - No menciona trabajo futuro o extensiones
# - No compara con estudios previos o datos de campo
#
# **Recomendación:**
# Agregar limitaciones del modelo, proponer extensiones con datos del SAG.

# %% [markdown]
# ## 7. Presentación y Calidad General (máx. 10 pts) — 10 / 10
