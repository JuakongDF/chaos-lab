# %% [markdown]
# Comparación del Tent Map en la Mancha Roja de Júpiter con los datos reales
# Marta Pacheco, Antonia Carvajal y Carolina Díaz
#
# A lo largo de los años el ser humano ha intentado entender la Mancha Roja de Júpiter, su comportamiento caótico y extraño cautiva generaciones de científicos. Pero ¿Se ha logrado entenderla? la verdad no, se conoce poco al respecto, debido que su conducta es distinta a la terrestre. Se sabe que la Mancha Roja de Júpiter es una enorme tormenta anticiclónica en su atmósfera, la más grande del Sistema Solar, que es una región persistente de alta presión y nubes. Se caracteriza por vientos de hasta 680 km en su borde y una duración que supera los 300 años. Si bien su tamaño puede parecer intimidante, se ha estado encogiendo a lo largo del tiempo, en un principio su diámetro era de 39,000 km y actualmente solo llega 14,000 km, una diferencia muy grande.
#
# Marco Teórico
# - 𝑥n: estado del sistema en el paso $n$ (normalizado entre 0 y 1)
# - μ: parámetro de control (típicamente 0 < μ ≤ 2)
# - Para μ = 2: caos completamente desarrollado
# - Forma de "carpa": sube linealmente hasta 0.5, luego baja linealmente
#
#
# El modelo elegido para este estudio es el Mapa de la Tienda de Campaña (Tent Map), un sistema dinámico discreto, unidimensional y por tramos lineal. Es un modelo ampliamente utilizado en la teoría del caos debido a su simplicidad matemática, ya que sus ecuaciones son lineales por tramos, pero su comportamiento dinámico es tan rico y complejo como el de otros modelos no lineales más conocidos, como el mapa logístico. A diferencia de este último, que es parabólico, el mapa de la tienda de campaña tiene una forma triangular o de "tienda de campaña" cuando se grafica.
# Este modelo es fundamental para demostrar conceptos clave de los sistemas caóticos, como la sensibilidad a las condiciones iniciales, la bifurcación y la transición al caos.
#
# El comportamiento esperado en una simulación varía en función del valor de μ:
# μ < 1: Convergencia a un punto fijo (0). Las iteraciones del mapa se acercan progresivamente a 0, independientemente del valor inicial x0.
# μ = 1: Convergencia a un punto fijo o comportamiento periódico simple.
# 1 < μ < 2: Comportamiento caótico para la mayoría de los valores iniciales. Las trayectorias no convergen a un punto fijo ni a un ciclo periódico simple, sino que exploran el intervalo [0, μ/2] de forma errática e impredecible a largo plazo.
# μ = 2: Comportamiento caótico y distribución uniforme. En este punto, el sistema es completamente caótico y, tras un gran número de iteraciones, la distribución de los valores xn tiende a ser uniforme en el intervalo [0,1].
# μ > 2: Escape o divergencia. La mayoría de las trayectorias salen del intervalo [0,1] y divergen (tienden a infinito negativo o positivo, dependiendo del intervalo exacto).

# %% [markdown]
# Comparación del Tent Map en la Mancha Roja de Júpiter con los datos reales
# Marta Pacheco, Antonia Carvajal y Carolina Díaz
#
# Abstract:
#
# El documento analiza las discrepancias entre las simulaciones numéricas del encogimiento de la Gran Mancha Roja (GMR) de Júpiter y las observaciones reales. La investigación compara las predicciones de los modelos atmosféricos con datos históricos del Hubble y Juno. El objetivo es determinar cómo varía la simulación con respecto a la realidad, discutiendo factores como la absorción de tormentas más pequeñas, la variación en la altura del vórtice y la necesidad de modelos tridimensionales más complejos.
#
# Este estudio explora las dinámicas no lineales del Mapa de la Tienda de Campaña (Tent Map), un sistema dinámico discreto, unidimensional y por tramos lineal. Elegido por su simplicidad matemática y su capacidad para ilustrar fenómenos caóticos complejos, el modelo sirve como una herramienta pedagógica fundamental en la teoría del caos, comparable en riqueza dinámica al más conocido mapa logístico no lineal.
#
# Palabras Clave: Sistemas Dinámicos Discretos, Teoría del Caos, Mapa de la Tienda de Campaña (Tent Map).
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Introducción:
#
# A lo largo de los años el ser humano ha intentado entender la Mancha Roja de Júpiter, su comportamiento caótico y extraño cautiva generaciones de científicos. Pero, ¿se ha logrado entenderla? La verdad no, se conoce poco al respecto, debido a que su conducta es distinta a la terrestre. Se sabe que la Mancha Roja de Júpiter es una enorme tormenta anticiclónica en su atmósfera, la más grande del Sistema Solar, que es una región persistente de alta presión y nubes. Se caracteriza por vientos de hasta 680 km en su borde y una duración que supera los 300 años. Si bien su tamaño puede parecer intimidante, se ha estado encogiendo a lo largo del tiempo, en un principio su diámetro era de 39,000 km y actualmente solo llega 14,000 km, una diferencia muy grande. A partir de esta problemática decidimos  comparar un decrecimiento ideal usando Tent Map, el cual es un modelo matemático de tiempo discreto que describe un sistema dinámico y puede tener un comportamiento caótico, muestra caos "puro”, sirve para estudiar sensibilidad a condiciones iniciales y es muy útil para demostrar el "efecto mariposa”. Adaptándolo a nuestro caso, la Mancha Roja de Júpiter es un sistema complejo el cual tiene comportamientos muy diferentes dependiendo de la dinámica de vientos y tormentas a su alrededor, ya que absorbe tormentas más pequeñas. Esto es un misterio, ya que no tiene una explicación hidrodinámica clara, se conoce que a menor velocidad, mayor es su anchura, lo cual nos da una pequeña explicación de su decrecimiento, la velocidad de la mancha se ha acelerado entrando en un caos provocando una disminución en su tamaño, sin embargo tiene variaciones en un periodo de 90 días, donde su tamaño y luminosidad fluctúa, se cree que esto surge por la interacción de la radiación solar ultravioleta sobre metano, etano, dióxido de carbono o nitrógeno gaseoso pero según esta teoría, debería ser del color blanco. En teoría, fenómenos como la Gran Mancha Roja deberían seguir lo que se conoce como la relación de Kida, que vincula la vorticidad (La vorticidad es una magnitud física empleada en mecánica de fluidos y en el mundo meteorológico para cuantificar la rotación de un fluido.) y el tamaño de un vórtice. Sin embargo, los datos actuales sugieren que la GRS no sigue este patrón, lo que apunta a una complejidad subyacente en la dinámica de la tormenta que aún no se comprende por completo. A partir de todo esto realizamos la siguiente pregunta: ¿Cómo varía la simulación del encogimiento de la mancha roja de Júpiter con respecto a la realidad?. Luego redactamos la hipótesis: Se espera que en el tent map los valores de "r" para llegar a los diversos casos (extinción, ciclos, estabilidad o caos) tendrán diferencias leves a los del mapa logístico y solo variando en el caso del caos, ya que ambos modelos siguen una forma similar, pero a pesar de esto el tent map tiene una estructura donde el caos es más propenso de suceder (por su sensibilidad ante variaciones de los valores iniciales). A continuación, explicaremos y compararemos los resultados de la simulación del Tent Map con el comportamiento real observado de la Gran Mancha Roja para responder a nuestra pregunta de investigación y validar o refutar nuestra hipótesis.
# Marco Teórico
#
# FÓRMULA DEL TENT MAP:
#
#
# PARÁMETROS:
# - 𝑥n: estado del sistema en el paso $n$ (normalizado entre 0 y 1)
# - μ: parámetro de control (típicamente 0 < μ ≤ 2)
# - Para μ = 2: caos completamente desarrollado
# - Forma de "carpa": sube linealmente hasta 0.5, luego baja linealmente
#
#
# El modelo elegido para este estudio es el Mapa de la Tienda de Campaña (Tent Map), un sistema dinámico discreto, unidimensional y por tramos lineal. Es un modelo ampliamente utilizado en la teoría del caos debido a su simplicidad matemática, ya que sus ecuaciones son lineales por tramos, pero su comportamiento dinámico es tan rico y complejo como el de otros modelos no lineales más conocidos, como el mapa logístico. A diferencia de este último, que es parabólico, el mapa de la tienda de campaña tiene una forma triangular o de "tienda de campaña" cuando se grafica.
# Este modelo es fundamental para demostrar conceptos clave de los sistemas caóticos, como la sensibilidad a las condiciones iniciales, la bifurcación y la transición al caos.
#
# El comportamiento esperado en una simulación varía en función del valor de μ:
# μ < 1: Convergencia a un punto fijo (0). Las iteraciones del mapa se acercan progresivamente a 0, independientemente del valor inicial x0.
# μ = 1: Convergencia a un punto fijo o comportamiento periódico simple.
# 1 < μ < 2: Comportamiento caótico para la mayoría de los valores iniciales. Las trayectorias no convergen a un punto fijo ni a un ciclo periódico simple, sino que exploran el intervalo [0, μ/2] de forma errática e impredecible a largo plazo.
# μ = 2: Comportamiento caótico y distribución uniforme. En este punto, el sistema es completamente caótico y, tras un gran número de iteraciones, la distribución de los valores xn tiende a ser uniforme en el intervalo [0,1].
# μ > 2: Escape o divergencia. La mayoría de las trayectorias salen del intervalo [0,1] y divergen (tienden a infinito negativo o positivo, dependiendo del intervalo exacto).
#
#
# Implementación del Modelo:
#
# EXTINCIÓN:
#
#
# ESTABLE:
#
#
#
# CICLOS:
#
#
#
#
# CAOS:
#
#
# SERIES TEMPORALES:
#
#
#
#
#
#
#
# DIAGRAMA DE TELARAÑA:
#
#
#
#
#
#
#
#
#
# Análisis y Resultados:
#
#
# Simulación (r = 0.5):
# Interpretación Profunda: Como el multiplicador de la iteración es 0.5, el estado se reduce a la mitad en cada paso cerca de cero. El gráfico superior izquierdo muestra una convergencia exponencial extremadamente rápida hacia x = 0. El sistema exhibe un comportamiento asintóticamente estable.
# Simulación (r = 1.0):
# Interpretación Profunda: Marca la bifurcación o el límite de estabilidad. El gráfico superior derecho muestra una convergencia a x = 0 (o un valor muy cercano si el estado inicial ya era pequeño). El punto fijo es marginalmente estable o atractor débilmente; el sistema no diverge pero la tasa de convergencia se reduce significativamente en comparación con r = 0.5.
# Simulación (r = 1.1):
# Fase Transitoria: El gráfico inferior izquierdo muestra que la trayectoria inicialmente se aleja de x = 0 (el punto fijo inestable) y se acerca a la región central del intervalo.
# Ciclo Periódico: Después de n ≈ 15, el sistema se asienta en un ciclo límite de periodo 2 (oscilando entre dos valores fijos, xa ≈ 0.55 y xb ≈ 0.50).
# Simulación (r = 1.95):
# Interpretación Profunda: El gráfico inferior derecho exhibe un patrón de fluctuación errática que abarca prácticamente todo el rango $[0, 1]$.
# Comportamiento: La trayectoria no converge, no diverge y no repite ningún ciclo. Este es el sello de un sistema caótico.
#
# Los cuatro gráficos documentan la secuencia dinámica canónica del Mapa Tienda al aumentar el parámetro r:
#
# Parámetro (r)
# Dinámica Observada
# Estabilidad / Régimen
# 0.5
# Convergencia rápida a x = 0.
# Atractor Puntual (Estable)
# 1.0
# Convergencia a x = 0 (límite).
# Bifurcación (Pérdida de Estabilidad)
# 1.1
# Convergencia a un ciclo de periodo 2.
# Atractor Periódico (Ciclo Límite)
# 1.95
# Fluctuación irregular.
# Caos Deterministra
#
#
# El diagrama de bifurcación del Mapa Tienda es un modelo visual de cómo la dinámica de un sistema no lineal evoluciona de la simplicidad (punto fijo) a la complejidad (caos) con un simple aumento en el parámetro de control $r$:
# r ≤ 1: Orden total (convergencia a $x=0$).
# 1 < r ≤ 1.414: Dinámica periódica (ciclo de periodo 2).
# r → 2: Comportamiento caótico, caracterizado por el llenado de bandas y la presencia de ventanas periódicas de alta complejidad.
# El diagrama actúa como un mapa de carreteras que resume la estabilidad de todos los posibles atractores del sistema, verificando las transiciones dinámicas observadas en las series temporales específicas.
#
#
#
#
#
#
# COMPARACIÓN CON DATOS REALES:
#
#
#
# FUENTES:
#
# Aguilar, K (2019) Sistemas Dinámicos y Caos: Tent Map https://es.scribd.com/document/438566578/Sistems-dinamicos-y-caos-Tent-Map
# Liu, C - Ding, L y Ding, Q (2019) Research about the Characteristics of Chaotic Systems Based on Multi-Scale Entropy https://www.mdpi.com/1099-4300/21/7/663#:~:text=5.2.&text=The%20tent%20chaotic%20system%20is,is%20shown%20in%20Figure%209.&text=where%20x%200%20%E2%88%88%20%5B%200,one%20of%20the%20five%20regions.&text=Figure%2010.,%CE%BC%20and%20the%20corresponding%20variance.
#  Agrawal, D y Minocha, S (2023) Perspective of DNA Computing in Computer Science https://www.sciencedirect.com/topics/computer-science/chaotic-map#:~:text=Tent%20map:%20A%20tent%20map,3.
#
# Sánchez, A (2024) La Gran Mancha Roja de Júpiter tiene el tamaño de la Tierra y se formó hace 190 años
# https://www.nationalgeographic.com.es/ciencia/gran-mancha-roja-jupiter-tiene-tamano-tierra-y-se-formo-hace-190-anos_22566
#
# Parra, S (2024)  El enigma de la Gran Mancha Roja de Júpiter: un baile cósmico inesperado https://www.nationalgeographic.com.es/ciencia/enigma-gran-mancha-roja-jupiter-baile-cosmico-inesperado_23430
