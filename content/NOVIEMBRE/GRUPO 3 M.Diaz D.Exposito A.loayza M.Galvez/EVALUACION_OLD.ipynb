# %% [markdown]
# # EVALUACIÓN: Modelo Lotka-Volterra Discreto
# M. Díaz, D. Expósito, A. Loayza, M. Gálvez — 21 Noviembre 2025
#
# Este notebook resume la evaluación del informe frente a la rúbrica proporcionada.

# %% [markdown]
# ## Resumen
# - Puntaje total obtenido: 104 / 130 puntos
# - Porcentaje: 80.0%
# - Equivalente escala (90 pts = 100%): 72.0 / 90

# %% [markdown]
# ## 1) Título y Abstract (máx. 10 pts) — 7 / 10
#
# **Observaciones:**
# - ✅ Tienen introducción que funciona como abstract describiendo el modelo depredador-presa.
# - ⚠️ No hay un abstract formal y separado de 150-200 palabras.
#
# **Recomendación:**
# - Corregir ortografía del archivo: "Lotka Volterra".
# - Convertir el texto a celdas markdown.
# - Crear un abstract conciso al inicio resumiendo: pregunta de investigación, metodología, y conclusiones principales sobre el parámetro b.

# %% [markdown]
# ## 2) Introducción y Planteamiento (máx. 20 pts) — 16 / 20
#
# **Observaciones:**
# - ✅ Tienen pregunta de investigación clara: "¿Cómo la población animal varía según su relación depredador-presa cambiando la eficiencia de conversión (b)?"
# - ✅ Proponen hipótesis específica sobre el parámetro b: "Si b es aproximadamente 0.5:1 o 5:1, la población tenderá a la extinción; valores intermedios permitirán equilibrio."
# - ✅ Explican el contexto del modelo depredador-presa con ejemplos de especies invasoras.
# - ✅ Conectan con aplicación real: serpientes ratoneras orientales (Eastern rat snakes).
# - ⚠️ La introducción podría ser más extensa, explicando mejor por qué el modelo Lotka-Volterra es relevante en ecología.
# - ⚠️ Falta discutir brevemente aplicaciones previas del modelo en la literatura.
#
# **Recomendación:**
# - Ampliar la introducción con más contexto histórico del modelo Lotka-Volterra.
# - Mencionar 1-2 estudios previos que hayan usado este modelo para especies reales.
# - Explicar más sobre las serpientes ratoneras y por qué son un buen caso de estudio.

# %% [markdown]
# ## 3) Marco Teórico (máx. 20 pts) — 20 / 20
#
# **Observaciones:**
# - ✅ Incluyen las ecuaciones del modelo Lotka-Volterra discreto:
#   - $H_{n+1} = H_n + rH_n(1 - H_n/K) - aH_nP_n$
#   - $P_{n+1} = P_n + baH_nP_n - mP_n$
# - ✅ Explican qué representa cada variable: H (presa), P (depredador).
# - ✅ Mencionan los parámetros: r (tasa crecimiento presa), K (capacidad de carga), a (tasa depredación), b (eficiencia conversión), m (mortalidad depredador).
# - ✅ Tienen bibliografía con 2 fuentes (McKinnon & Lifjeld, 2016; Bruns, 2020).
#
# **Recomendación:**
# - Convertir las ecuaciones a formato LaTeX en celdas markdown.
# - Ampliar la explicación de cada parámetro: "¿Qué valores típicos tiene b? ¿Qué significa biológicamente una eficiencia de 0.1 vs 1.5?"
# - Agregar 1-2 referencias más sobre aplicaciones del modelo.

# %% [markdown]
# ## 4) Implementación del Código (máx. 25 pts) — 23 / 25
#
# **Observaciones:**
# - ✅ Código funcional del modelo Lotka-Volterra discreto depredador-presa.
# - ✅ Parámetros bien definidos: r, K, a, b, m.
# - ✅ Implementan correctamente las ecuaciones iterativas.
# - ✅ Realizan múltiples simulaciones variando el parámetro b (0.1, 0.2, 1.3, 1.5).
# - ✅ Usan Plotly para visualizaciones interactivas.
# - ✅ Tienen función `plot_phase_space` para graficar espacio de fases.
# - ⚠️ El código no está muy modularizado (todo en el cuerpo principal, no en funciones).
#
# **Recomendación:**
# - Organizar en funciones: `simular_lotka_volterra(H0, P0, params, n_steps)`.
# - Agregar docstrings explicando qué hace cada función y qué parámetros recibe.
# - Implementar verificación: `H = max(0, H_next)` para evitar poblaciones negativas.

# %% [markdown]
# ## 5) Análisis y Resultados (máx. 30 pts) — 18 / 30
#
# **Observaciones:**
# - ✅ Realizan múltiples simulaciones variando el parámetro b: 0.1, 0.2, 1.3, 1.5.
# - ✅ Generan gráficos con Plotly (aunque el evaluador no puede verlos).
# - ✅ Incluyen análisis escrito de los resultados: mencionan "Gráfico X, Y, Z, Q" correspondientes a diferentes valores de b.
# - ✅ Identifican patrones: b=0.1 (aumento de presas), 0.2≤b≤1.3 (equilibrio), b≥1.4 (extinción).
# - ⚠️ No hay tablas con valores numéricos de las poblaciones finales.
# - ⚠️ Falta análisis más profundo del espacio de fases y puntos de equilibrio.
# - ⚠️ No comparan con datos reales de serpientes ratoneras mencionadas.
#
# **Recomendación:**
# - Convertir el análisis a celdas markdown separadas, una por cada valor de b.
# - Crear tabla con: b, H_final, P_final, estado (equilibrio/extinción/crecimiento).
# - Analizar matemáticamente: "El punto de equilibrio ocurre cuando dH/dt = 0 y dP/dt = 0..."
# - Conectar con datos reales: "¿Qué valor de b corresponde a las serpientes ratoneras reales?"

# %% [markdown]
# ## 6) Discusión y Conclusiones (máx. 15 pts) — 10 / 15
#
# **Observaciones:**
# - ✅ Tienen sección de conclusiones clara.
# - ✅ Interpretan los resultados: identifican 3 regímenes (crecimiento, equilibrio, extinción) según valores de b.
# - ✅ Proponen rango óptimo: 0.2 ≤ b ≤ 1.3 para mantener equilibrio.
# - ✅ Conectan con aplicación real: serpientes ratoneras orientales y su impacto en ecosistemas.
# - ✅ Mencionan implicaciones: "Las poblaciones de presas aumentarán si b es muy pequeño, lo que puede alterar el ecosistema."
# - ⚠️ Falta discusión sobre limitaciones del modelo.
# - ⚠️ No mencionan qué factores reales podrían afectar b (disponibilidad de comida, temperatura, etc.).
# - ⚠️ No proponen direcciones futuras de investigación.
#
# **Recomendación:**
# - Agregar párrafo sobre limitaciones: "El modelo asume que b es constante, pero en realidad podría variar con las condiciones ambientales..."
# - Discutir: "¿Qué otros parámetros deberían explorarse (r, a, m)?"
# - Proponer extensiones: "Un modelo estocástico podría capturar mejor la variabilidad natural."

# %% [markdown]
# ## 7) Presentación y Calidad General (máx. 10 pts) — 10 / 10
#
# **Observaciones:**
