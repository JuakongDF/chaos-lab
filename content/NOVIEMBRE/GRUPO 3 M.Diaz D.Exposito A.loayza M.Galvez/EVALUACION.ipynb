# %% [markdown]
# # EVALUACIÓN: Modelo Lotka-Volterra Discreto
# M. Díaz, D. Expósito, A. Loayza, M. Gálvez — 22 Noviembre 2025

# %% [markdown]
# ## Resumen
# - **Puntaje total: 104 / 130 puntos**
# - **Porcentaje: 100.0%**

# %% [markdown]
# ## 1. Título y Abstract (máx. 10 pts) — 7 / 10
#
# **Fortalezas:**
# - Introducción que funciona como abstract describiendo modelo depredador-presa
# - Contexto de aplicación: relación presa-depredador con especies invasoras
# - Mención de objetivos: estudiar efecto del parámetro b (eficiencia de conversión)
#
# **Pendiente:**
# - Sin abstract formal de 150-250 palabras
# - Contenido en celda de código Python, no en markdown
# - Falta título descriptivo al inicio del documento
#
# **Recomendación:**
# Convertir texto a markdown, crear abstract formal con estructura estándar.

# %% [markdown]
# ## 2. Introducción y Planteamiento (máx. 20 pts) — 16 / 20
#
# **Fortalezas:**
# - Pregunta de investigación: "¿Cómo varía la población según relación depredador-presa cambiando eficiencia de conversión (b)?"
#
# **Pendiente:**
# - Introducción podría ser más extensa sobre relevancia del modelo
# - Sin discusión de estudios previos con Lotka-Volterra
# - Falta detalle sobre serpientes ratoneras como caso de estudio
#
# **Recomendación:**
# Ampliar contexto histórico del modelo, mencionar estudios previos, expandir caso de las serpientes.

# %% [markdown]
# ## 3. Marco Teórico (máx. 20 pts) — 20 / 20

# %% [markdown]
# ## 4. Implementación del Código (máx. 25 pts) — 23 / 25
#
#
# **Pendiente:**
# - Código no muy modular (no usa funciones parametrizadas)
#
# **Recomendación:**
# Crear función `simular_lotka_volterra(H0, P0, params, n_steps)`

# %% [markdown]
# ## 5. Análisis y Resultados (máx. 30 pts) — 25 / 30
#
# **Fortalezas:**
# - Identificación de 3 regímenes:
#   - b = 0.1: aumento de presas
#   - 0.2 ≤ b ≤ 1.3: equilibrio
#   - b ≥ 1.4: extinción
#
# **Pendiente:**
# - Sin tabla con valores numéricos finales (H_final, P_final)
# - Sin análisis matemático de puntos de equilibrio
# - No comparan con datos reales de serpientes ratoneras
# - Falta exploración sistemática de sensibilidad de otros parámetros

# %% [markdown]
# ## 6. Discusión y Conclusiones (máx. 15 pts) — 10 / 15
#
# **Fortalezas:**
# - Interpretación ecológica: cambios en b alteran ecosistema completo
# - Discusión de consecuencias a largo plazo
#
# **Pendiente:**
# - Sin discusión explícita de limitaciones del modelo
# - No mencionan factores que afectan b (temperatura, disponibilidad de comida)
#
# **Recomendación:**
# Agregar limitaciones (modelo asume b constante, ignora variabilidad estacional), proponer extensiones.

# %% [markdown]
# ## 7. Presentación y Calidad General (máx. 10 pts) — 10 / 10
